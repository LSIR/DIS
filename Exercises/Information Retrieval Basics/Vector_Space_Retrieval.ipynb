# %% [markdown]
# ## 📚 Exercise 1
# In this exercise, we will understand the functioning of TF/IDF ranking and implement and test a vector space retrieval model.
#
# ### Use case:
# You are an engineer who is building a search engine for the recipe finder application _bestbakesinthebuilding.com_. In this application, users can search for their favorite recipe, ingredients, or any recipe-relevant term. The search engine should return relevant recipes that are stored in the website's DB. For the implementation of the searching functionality, you have to use the vector space retrieval model.
#
# To build your system, you have available recipe data in the file bread.txt which is a dump from the application's DB.
#
# The schema of the data is the following:
#
#   DocID | Document Text
#   ------|------------------
#   1     | How to Bake Breads Without Baking Recipes
#   2     | Smith Pies: Best Pies in London
#   3     | Numerical Recipes: The Art of Scientific Computing
#   4     | Breads, Pastries, Pies, and Cakes: Quantity Baking Recipes
#   5     | Pastry: A Book of Best French Pastry Recipes
#
#
# ### Goal:
# 1. Preprocess the input text by tokenizing it and stemming it.
# 2. Vectorize the preprocessed text by implementing the TF/IDF function.
# 3. Test your method by searching for the query $Q = ``baking''$ and find the top-ranked documents according to the TF/IDF rank.
# 4. Compare your implementation with the existing implementation of scikit-learn library.
#
# ### What are you learning in this exercise:
# - Vector space retrieval model implementation.
# - TF/IDF ranking.
# - Evaluation of a text retrieval system.

# %%
# Loading of libraries and documents
from nltk.stem import PorterStemmer, WordNetLemmatizer
import nltk
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.metrics.pairwise import linear_kernel
import string
from nltk.corpus import stopwords
import math
from collections import Counter
from operator import itemgetter
nltk.download('stopwords')
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package stopwords to /Users/zns/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /Users/zns/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %% [markdown]
# #### 1. Preprocess the input text by tokenizing it and stemming it.

# %%
stemmer = PorterStemmer() 
def tokenize(text):
    """
    It tokenizes and stems an input text.
    
    :param text: str, with the input text
    :return: list, of the tokenized and stemmed tokens.
    """
    text = "".join([ch for ch in text if ch not in string.punctuation])
    tokens = nltk.word_tokenize(text)
    return [stemmer.stem(word.lower()) for word in tokens if word not in stopwords.words('english')]

# Read a list of documents from a file. Each line in a file is a document
with open("epfldocs.txt") as f:
    content = f.readlines()
original_documents = [x.strip() for x in content] 
documents = [tokenize(d) for d in original_documents]

documents
# Out:
# [['congrat',
#   'ethen',
#   '5th',
#   'place',
#   'epflen',
#   '10th',
#   'place',
#   'httpstco8rlp0zzhyb'],
#  ['if', 'that', 'stand', 'ovat', 'epflen', '🏆🙃😜👾🚀🎉', 'httpstco23kjig8pxt'],
#  ['time',
#   'open',
#   'farm',
#   'pitch',
#   'openfood',
#   'opendata',
#   'epfl',
#   'httpstco7lkkao5780'],
#  ['good',
#   'opportun',
#   'ethen',
#   'epflen',
#   'epflpark',
#   'uzhnewsen',
#   'httpstcov3tojtyjqd'],
#  ['excit',
#   'news',
#   'world',
#   'univers',
#   'rank',
#   '20162017',
#   'subject',
#   'comput',
#   'scienc',
#   'no1',
#   'eth',
#   'amp',
#   'epfl',
#   'no8',
#   'congrat',
#   'httpstcoarslxzoshq'],
#  ['epfl',
#   'cryptotoken',
#   'free',
#   'energi',
#   'httpstcovh9qgloqrr',
#   'httpstco6utnj68psc',
#   'httpstcogtxlhi6lt',
#   'httpstcozyenraseir',
#   'get',
#   'rich'],
#  ['scientist',
#   'discov',
#   'hidden',
#   'pattern',
#   'brain',
#   'activ',
#   'httpstcohblrytdmtt',
#   'epfl'],
#  ['edacyhq', 'with', 'edaci', 'invest', 'httpstcox2y212dkup'],
#  ['deadlin',
#   '19052017',
#   'against',
#   'breast',
#   'cancer',
#   'i',
#   'research',
#   'fund',
#   'httpstcol4mhqa7upb',
#   'epfl',
#   'againstbc'],
#  ['robot',
#   'transform',
#   'furnitur',
#   'epfl',
#   'novemb',
#   'kamiahok',
#   'httpstcojjpc1puyum'],
#  ['microsoft',
#   'presid',
#   'bradsmi',
#   'epfl',
#   'ebugnion',
#   'wef18',
#   'digitalgenevaconvent',
#   'digitaltrust',
#   'import',
#   'topic',
#   'ethrat',
#   'epflen',
#   'httpstcoxg2cmw3szm'],
#  ['ateli',
#   'de',
#   'travail',
#   'sur',
#   'la',
#   'futur',
#   'traversé',
#   'de',
#   'la',
#   'rade',
#   'à',
#   'genev',
#   'avec',
#   'cantongenev',
#   'epfl',
#   'hslu',
#   'etc',
#   'et',
#   'la',
#   'hesso',
#   'hei',
#   'hepia',
#   'heiafr',
#   'httpstco2vqqgqhact'],
#  ['formid',
#   'je',
#   'sui',
#   'fan',
#   'du',
#   'projet',
#   'de',
#   'la',
#   'time',
#   'machin',
#   'il',
#   'sera',
#   'donc',
#   'possibl',
#   'de',
#   'revoir',
#   'la',
#   'conférenc',
#   'sur',
#   'votr',
#   'chaîn',
#   'youtub',
#   'si',
#   'jai',
#   'bien',
#   'lu',
#   'le',
#   'précédent',
#   'commentair',
#   'merci',
#   'de',
#   'signal',
#   'quand',
#   'cett',
#   'dernièr',
#   'sera',
#   'en',
#   'lign',
#   'archiv',
#   'numeriqu',
#   'httpstcortxwav5pan'],
#  ['the',
#   '27',
#   'member',
#   'wef',
#   'global',
#   'univers',
#   'leader',
#   'forum',
#   'includ',
#   'switzerland',
#   'ethen',
#   'epflen',
#   'respons',
#   'larg',
#   'proport',
#   'world',
#   '’',
#   'scientif',
#   'public',
#   'new',
#   'studi',
#   'reveal',
#   'httpstcon2fe3bxfzh',
#   'httpstcokpg9gtylsq'],
#  ['switzerland',
#   'work',
#   'hard',
#   'keep',
#   'best',
#   'brjsa',
#   'robot',
#   'srindustryday',
#   'httpstcojosupjdg7k'],
#  ['free',
#   'yoga',
#   'event',
#   'host',
#   'indian',
#   'student',
#   'epfl',
#   'lausann',
#   'ambassador',
#   'gill',
#   'cdmissionindia',
#   'attend',
#   'unil',
#   'myswitzerlandf',
#   'epflen',
#   'httpstcoxnciwuqcxw'],
#  ['aviat',
#   'la',
#   'suiss',
#   'désormai',
#   'son',
#   'centr',
#   'de',
#   'recherch',
#   'aéronautiqu',
#   'zhaw',
#   'hsgstgallen',
#   'epfl',
#   'via',
#   'swissinfofr',
#   'httpstcoyrv8tyelk7'],
#  ['scirobot',
#   'live',
#   'facebook',
#   'watch',
#   'epflen',
#   'engin',
#   'show',
#   'versatil',
#   'vacuumpow',
#   'robot',
#   'httpstcofzp3zsaqyn'],
#  ['“',
#   'for',
#   'eu',
#   'countri',
#   'switzerland',
#   'interest',
#   'laboratori',
#   '”',
#   'httpstco94kl7dmd6z',
#   'epfl'],
#  ['fantast',
#   'explan',
#   'blockchain',
#   'blockchain',
#   'fintech',
#   'startup',
#   'epflen',
#   'swissborg',
#   'cltucci',
#   'httpstcoovrho1wvs6'],
#  ['présentat',
#   'du',
#   'nouveau',
#   'guid',
#   'robotiqu',
#   'en',
#   'éducat',
#   'au',
#   'cour',
#   'de',
#   'la',
#   'format',
#   'thymioii',
#   'hep',
#   'httpstco5tamwdmspa',
#   'fmondada',
#   'epfl',
#   'httpstcojb7mkkvqdd'],
#  ['i',
#   'would',
#   'trust',
#   'ai',
#   'doctor',
#   'human',
#   'one',
#   'marcelsalath',
#   'epflen',
#   'it',
#   'listen',
#   '247',
#   'how',
#   'human',
#   'compet',
#   'aihealth',
#   'swsx'],
#  ['nice',
#   'bbcradio4',
#   'anim',
#   'fourthrevolut',
#   'luciano',
#   'floridi',
#   'uniofoxford',
#   'httpstco9oq2y42cox',
#   'agepoli',
#   'epflen',
#   'epfl',
#   'httpstcojr2dh5kofq'],
#  ['epfl',
#   'mooc',
#   'two',
#   'million',
#   'regist',
#   'user',
#   'switzerland',
#   'httpstcot528zfgtmn'],
#  ['trace',
#   'possibl',
#   'martian',
#   'biolog',
#   'activ',
#   'insid',
#   'meteorit',
#   'httpstcopzu3ng1vmp',
#   'oscienc',
#   'epflen',
#   'mar',
#   'httpstco4l1kod6rgm'],
#  ['ehr',
#   'für',
#   'schweizer',
#   'vmwaremitgründ',
#   'ebugnion',
#   'httpstcoancm3qlido',
#   'herzlich',
#   'gratul',
#   'epfl'],
#  ['etr',
#   'bien',
#   'positionné',
#   'au',
#   'départ',
#   'sera',
#   'la',
#   'clef',
#   '🇨🇭merci',
#   'et',
#   'bravo',
#   'à',
#   'epfl',
#   'qui',
#   'ne',
#   'ménage',
#   'pa',
#   'se',
#   'effort',
#   'en',
#   'la',
#   'matièr',
#   'contribu',
#   'à',
#   'la',
#   'prospérité',
#   'à',
#   'la',
#   'compétitivité',
#   'et',
#   'à',
#   'la',
#   'modernité',
#   'du',
#   'pay',
#   'sur',
#   'le',
#   'long',
#   'term',
#   'httpstcofiup9zphwo'],
#  ['join',
#   'mediaroad',
#   'team',
#   'talk',
#   'media',
#   'innov',
#   'expert',
#   '2',
#   'march',
#   '2018',
#   'geneva',
#   'the',
#   'upcom',
#   'event',
#   'organ',
#   'epfl',
#   'take',
#   'ai',
#   'fakenew',
#   'socialmedia',
#   'data',
#   'httpstcox8uurri5oy'],
#  ['epfl',
#   'sv',
#   'bms2018',
#   'brain',
#   'mind',
#   'institut',
#   'symposium',
#   'summer',
#   '2018',
#   'stress',
#   'health',
#   'diseas',
#   'switzerland',
#   'httpstcolmivlno9zr'],
#  ['cyclometal',
#   'ruthenium',
#   'complex',
#   'dyesensit',
#   'solar',
#   'cell',
#   'httpstco5t7egh0quw',
#   'epfl'],
#  ['new',
#   'epflen',
#   'life',
#   'scienc',
#   'epflsv',
#   'from',
#   'phd',
#   'directli',
#   'independ',
#   'group',
#   'leader',
#   'elfirepfl',
#   'earli',
#   'independ',
#   'research',
#   'scholar',
#   'see',
#   'httpstcoevqyqd7ffl',
#   'also',
#   'comput',
#   'biolog',
#   'compbio',
#   'httpstcoe3pdcg6nvb',
#   'deadlin',
#   'april',
#   '1',
#   '2018',
#   'httpstcomjqcrfiqkb'],
#  ['ecorobotix',
#   'present',
#   'develop',
#   'weed',
#   'robot',
#   'epfl',
#   'start',
#   'confer',
#   '11am',
#   'httpstcobvfd0ag6bg',
#   'epfl'],
#  ['dougla',
#   'hanahan',
#   'isrec',
#   'epfl',
#   'give',
#   'final',
#   'close',
#   'lectur',
#   '‘',
#   'microenvironment',
#   'determin',
#   'invas',
#   'amp',
#   'metastast',
#   '’',
#   'lornecanc',
#   '2018',
#   'lcc2018',
#   'cancer',
#   'metastasi',
#   'nottheashleydunnor',
#   'httpstco0iqt3k8fkq'],
#  ['appli',
#   'machin',
#   'learn',
#   'day',
#   'main',
#   'event',
#   'kick',
#   'epfl',
#   '1200',
#   'practition',
#   'hous',
#   'cisco',
#   'proud',
#   'sponsor',
#   'amld2018',
#   'httpstcohqep6odmnw'],
#  ['ml',
#   'tutori',
#   'timeseri',
#   'sequenc',
#   'data',
#   'apachemxnet',
#   'gluon',
#   'httpstcoojfrwo2glw',
#   'plenti',
#   'introductori',
#   'materi',
#   'deeplearn',
#   'timeseri',
#   'present',
#   'appliedmlday',
#   'epfl'],
#  ['sestrin1',
#   'identifi',
#   'epflen',
#   'research',
#   'gene',
#   'frequent',
#   'miss',
#   'mutat',
#   'follicular',
#   'lymphoma',
#   'httpstcoveig9f8bpl',
#   'httpstcojqle5pexa4'],
#  ['colorselect',
#   'amp',
#   'versatil',
#   'light',
#   'steer',
#   'w',
#   'upscal',
#   'subwavelength',
#   'planar',
#   'optic',
#   'cseminfo',
#   'epflen',
#   'httpstcoztbmsxxp3x',
#   'httpstcozl8ig3vbau'],
#  ['mobil', 'crowdsourc', 'epflen', 'campu', 'httpstconctmpw0ba3'],
#  ['paulg', 'come', 'epflen', 'hardwork', 'student'],
#  ['march',
#   '9',
#   'genev',
#   'smart',
#   'citi',
#   'aujourdhui',
#   'et',
#   'demain',
#   'unigenew',
#   'siggenev',
#   'epflen',
#   'secheronsa',
#   'plrge',
#   'httpstcotqwfwbeq8c',
#   'httpstcoxng9dhji4'],
#  ['jimharri',
#   'epfl',
#   'campu',
#   'world',
#   'first',
#   'solar',
#   'window',
#   'httpstcovnm71za5m0',
#   'epfl'],
#  ['enrol',
#   'free',
#   'epflen',
#   'iucn',
#   'mooc',
#   'ecolog',
#   'monitor',
#   'essenti',
#   'protect',
#   'area',
#   'httpstcoepj0zoeiiz',
#   'ecolog'],
#  ['celebr',
#   'nobelpr',
#   'winner',
#   'jaqu',
#   'dubochet',
#   'unil',
#   'lausann',
#   'vaud',
#   'proud',
#   'heclausann',
#   'epfl',
#   'httpstcotu6j8j44kl'],
#  ['epfl',
#   'valai',
#   'une',
#   'bours',
#   'de',
#   'troi',
#   'million',
#   'pour',
#   'étudier',
#   'le',
#   'avc',
#   'switzerland',
#   'httpstcovnv2ldposj'],
#  ['it',
#   '’',
#   'possibl',
#   'film',
#   'quantum',
#   'mechan',
#   '–',
#   'paradox',
#   'natur',
#   '–',
#   'directli',
#   'here',
#   'light',
#   'photograph',
#   'wave',
#   'amp',
#   'particl',
#   'first',
#   'time',
#   'via',
#   'epflen',
#   'epfl',
#   'httpstcom3h6iyav3k'],
#  ['research',
#   'observ',
#   'weather',
#   'process',
#   'previous',
#   'known',
#   'occur',
#   'antarctica',
#   'httpstcomdanih1v5h',
#   'via',
#   'epflen'],
#  ['ict4develop',
#   'conf',
#   '2018',
#   'lausann',
#   'join',
#   'us',
#   'ict4dev',
#   'rural',
#   'circular',
#   'digit',
#   'platform',
#   'httpstconf1gerzfun',
#   'epfl',
#   'epflcampu'],
#  ['lepfl',
#   'sera',
#   'la',
#   'capital',
#   'de',
#   'drone',
#   'début',
#   'septembr',
#   'httpstcoqdxcmza3bv',
#   'epfl'],
#  ['📍hannov',
#   'mess',
#   '2017',
#   'hm17',
#   '✊📰',
#   'mechatronik',
#   'begreifbar',
#   'messestand',
#   'von',
#   'kukaroboticsd',
#   'manchu',
#   'epflen',
#   'kuka',
#   'innov',
#   'award',
#   '2017',
#   'httpstcoofmfg5uwf'],
#  ['martinvetterli',
#   'epfl',
#   'setzt',
#   'sich',
#   'für',
#   'open',
#   'scienc',
#   'ein',
#   'wissen',
#   'teilen',
#   'für',
#   'mehr',
#   'wirkung',
#   'httpstco4hmazta9qa'],
#  ['marcelsalath',
#   'epflen',
#   'michielrauws2',
#   'x2ai',
#   'if',
#   'personifi',
#   'ai',
#   'deceiv',
#   'trust',
#   'effyvayena',
#   'uzhnew',
#   'ask',
#   'aihealth',
#   'sxsw',
#   'sxswiss'],
#  ['nou',
#   'aussi',
#   'sait',
#   'fair',
#   'en',
#   'franc',
#   'de',
#   'la',
#   'façad',
#   'solair',
#   'httpstcokf6e0am2kb'],
#  ['i',
#   'switzerland',
#   'brjsa',
#   'unil',
#   'epfl',
#   'swisssporttv',
#   'remnantnew',
#   'jesusmessiah7',
#   'httpstcofhtmlunack',
#   'etatdevaud',
#   'communelausann',
#   'httpstco4agkuwothi'],
#  ['congrat',
#   'sensima',
#   'inspect',
#   'grant',
#   'chf',
#   '3',
#   'million',
#   'loan',
#   'sg',
#   'httpstcolmdqyovvl9',
#   'vdtech',
#   'cc',
#   'epflen',
#   'httpstcogbdmfiztsk'],
#  ['swiss',
#   'feder',
#   'institut',
#   'technolog',
#   'ethen',
#   'epflen',
#   'open',
#   'nation',
#   'center',
#   'datasci',
#   'httpstcodosw7ttzm0'],
#  ['aziz',
#   'heddi',
#   'dynamicsmechan',
#   'weevilsodali',
#   'interact',
#   'lifespan',
#   'highlight',
#   'continuum',
#   'symbionthost',
#   'interact',
#   'fems2017'],
#  ['bienvenu',
#   'à',
#   'ariel',
#   'mahamad',
#   'eddi',
#   'et',
#   'mactar',
#   'de',
#   'la',
#   '1ère',
#   'cohort',
#   'du',
#   'programm',
#   'edacyhq',
#   'qui',
#   'débutent',
#   'leur',
#   'stage',
#   'aujourdhui',
#   '😊💪',
#   'httpstcovsh31g6vpl'],
#  ['launch',
#   'imdepfl',
#   'transformtech',
#   'program',
#   'welcom',
#   'particip',
#   'martinvetterli',
#   'epfl',
#   'imd',
#   'httpstcoznphy0ralc'],
#  ['mrhiura',
#   'marcelsalath',
#   'epflen',
#   'forumepfl',
#   'it',
#   '’',
#   'one',
#   'thing',
#   'censor',
#   '’',
#   'anoth',
#   'avoid',
#   'promot',
#   'agenda',
#   'tbh',
#   'student',
#   'realli',
#   'confus',
#   'httpstco856yhgi74j'],
#  ['just', 'effyvayena', 'eth', 'everyon', 'els', 'epfl', 'httpstco06jmxdae2h'],
#  ['eth',
#   'board',
#   'releas',
#   'new',
#   'gender',
#   'strategi',
#   'at',
#   'appli',
#   'machin',
#   'learn',
#   'day',
#   '’',
#   'excit',
#   'offer',
#   'childcar',
#   'help',
#   'support',
#   'epfl',
#   'trekkinglemon',
#   'martinvetterli',
#   'httpstcoho0yhh1i4b',
#   'httpstco7vf2txcuio'],
#  ['rlerigni',
#   'epfl',
#   'la',
#   'norm',
#   '690',
#   'est',
#   'théoriqu',
#   'en',
#   'pratiqu',
#   'si',
#   'lextensoetudian',
#   'fait',
#   '1',
#   'csl',
#   'zotero',
#   'sur',
#   'une',
#   'norm',
#   'proprio',
#   'je',
#   'la',
#   'prendrai'],
#  ['connect',
#   'event',
#   'sconnect',
#   'epfl',
#   'ur',
#   'lehner',
#   'swisscom',
#   'le',
#   'défi',
#   'et',
#   'le',
#   'enjeux',
#   '’',
#   'intellig',
#   'artificiel',
#   'sont',
#   'considér',
#   'vdtech',
#   'httpstcoerqa06qoiy'],
#  ['bravo',
#   'à',
#   'tou',
#   'le',
#   'membr',
#   'du',
#   'think',
#   'tank',
#   'iot',
#   'pour',
#   'tout',
#   'le',
#   'travail',
#   'fourni',
#   'en',
#   '2017',
#   'découvrez',
#   'le',
#   'livr',
#   'de',
#   'restitut',
#   'avec',
#   'une',
#   'citat',
#   'de',
#   'didier',
#   'mesnier',
#   'notr',
#   'secrétair',
#   'exécutif',
#   'micronarc',
#   'cseminfo',
#   'hesso',
#   'epfl',
#   'httpstcok7yxc6cht5'],
#  ['less',
#   '30',
#   'univers',
#   'produc',
#   'research',
#   'entir',
#   'industri',
#   'nation',
#   'proud',
#   'epflen',
#   'ethen',
#   'part',
#   'gulf',
#   'group',
#   'wef18',
#   'httpstcobcumzs50wo',
#   'httpstcormxjlczif6',
#   'ethrat',
#   'epfl',
#   'davo',
#   'httpstcooyguvk0le4'],
#  ['dtsbourg',
#   'mrhiura',
#   'marcelsalath',
#   'epflen',
#   'forumepfl',
#   'confus',
#   'epflen',
#   'inde',
#   'clear',
#   'respons',
#   'toward',
#   'swiss',
#   'societi',
#   'need',
#   'inform',
#   'hear',
#   'variou',
#   'voic',
#   'need',
#   'provid',
#   'input',
#   'debat'],
#  ['nucleosom',
#   'engag',
#   'shortliv',
#   'micro',
#   'millisecond',
#   'stack',
#   'interact',
#   'one',
#   'neighbor',
#   'gt',
#   'tetranucleosom',
#   'unit',
#   'hp1a',
#   'engag',
#   'methyl',
#   'histon',
#   'tail',
#   'therebi',
#   'transient',
#   'stabil',
#   'stack',
#   'nucleosom',
#   'thi',
#   'compact',
#   'state',
#   'nevertheless',
#   'remain',
#   'dynam',
#   'httpstco1ulb3gwmfp'],
#  ['trace',
#   'possibl',
#   'martian',
#   'biolog',
#   'activ',
#   'insid',
#   'meteorit',
#   'httpstcopzu3ng1vmp',
#   'oscienc',
#   'epflen',
#   'mar',
#   'httpstco4l1kod6rgm'],
#  ['workshop',
#   'decentr',
#   'messag',
#   'nextleap2020',
#   'epfl',
#   'lausann',
#   'tomorrow',
#   'jan',
#   '17',
#   'carmelatroncoso',
#   'hpk42',
#   'gdanezi',
#   'trevp',
#   'come',
#   'time',
#   'talk',
#   'small',
#   'group',
#   'discuss',
#   'exist',
#   'new',
#   'protocol'],
#  ['“',
#   'artifici',
#   'intellig',
#   'potenti',
#   'revolution',
#   'transport',
#   'interview',
#   'alexandr',
#   'alahi',
#   'new',
#   'professor',
#   'transport',
#   'engin',
#   'epfl',
#   'httpstcos8zkriahbq',
#   'rt',
#   'traceepfl',
#   'httpstcopqqkry5ny9'],
#  ['le',
#   'physicien',
#   'de',
#   'l',
#   'epfl',
#   'peuvent',
#   'lire',
#   'à',
#   'traver',
#   'un',
#   'livr',
#   'san',
#   'louvrir',
#   'le',
#   'testament',
#   'scellé',
#   'de',
#   'catharuçia',
#   'savonario',
#   'rivoalti',
#   'na',
#   'plu',
#   'de',
#   'secret',
#   'pour',
#   'eux',
#   'httpstcosoiiictqnr',
#   'via',
#   'archimagredac',
#   'httpstcoqvsxcayny7'],
#  ['improv',
#   'cooper',
#   'univers',
#   'amp',
#   'busi',
#   'one',
#   'main',
#   'challeng',
#   'eu',
#   'rampd',
#   'polici',
#   'accord',
#   'eusciencehub',
#   'httpstcoedkac9gul3',
#   'innov',
#   'tueindhoven',
#   'tumuenchen',
#   'epflen',
#   'dtutweet'],
#  ['gewch2017', 'kick', 'tomorrow', 'epflen', 'httpstco4rh442x4q1'],
#  ['new',
#   'studi',
#   'leukemia',
#   'offer',
#   'clearer',
#   'understand',
#   'biolog',
#   'httpstcomgxbfxvk1j',
#   'via',
#   'epflen',
#   'httpstcop7t3kzdyer'],
#  ['webot',
#   'simul',
#   'use',
#   'epfl',
#   'research',
#   'simul',
#   'insect',
#   'walk',
#   'naturecomm',
#   'articl',
#   'httpstcoglezs0jt7p',
#   'httpstcovhv9ame2i2'],
#  ['make',
#   'gigant',
#   'soap',
#   'bubbl',
#   'tutori',
#   'made',
#   'epfl',
#   'expert',
#   'httpstcoskukeuexpm'],
#  ['woopwoopsup',
#   'happylook',
#   'forward',
#   'work',
#   'hand',
#   'hand',
#   'covestrogroup',
#   'imdeanano',
#   'epflen',
#   'ujinoticia',
#   'imperialcolleg',
#   'etc',
#   'httpstco6lmgbkcsdb'],
#  ['🙌',
#   'congrat',
#   'ibm',
#   'scientist',
#   'irem\u200b',
#   'boybat',
#   'win',
#   'best',
#   'poster',
#   'award',
#   'synapt',
#   'architectur',
#   'last',
#   'week',
#   'ieeeorg',
#   'nvmt',
#   'njit',
#   'epfl',
#   'httpstcoq0oikdrfgg'],
#  ['stay',
#   'tune',
#   'we',
#   'announc',
#   'epflen',
#   'opensci',
#   'summer',
#   'school',
#   'next',
#   'week',
#   'fantast',
#   'speaker',
#   'great',
#   'workshop',
#   'httpstcozeu9qttta7'],
#  ['deephot',
#   'geotherm',
#   'energi',
#   'new',
#   'experiment',
#   'paper',
#   'scireport',
#   'epflen',
#   'highenthalpi',
#   'geotherm',
#   'httpstcoptjukxxkk4',
#   'httpstcouriy2wnepi'],
#  ['dnmason',
#   'violainese',
#   'cciliv',
#   'ani',
#   'chanc',
#   'imag',
#   'psf',
#   'andor',
#   'acquisit',
#   'meta',
#   'data',
#   'made',
#   'publicli',
#   'avail',
#   'id',
#   'like',
#   'test',
#   'imagejop',
#   'deconvolut',
#   'algorithm',
#   'deconvolutionlab2',
#   'produc',
#   'equival',
#   'result',
#   'btw',
#   'measurecomput',
#   'psf'],
#  ['le',
#   'vélo',
#   'de',
#   'étudiant',
#   'en',
#   'vacanc',
#   'bien',
#   'en',
#   'sécurité',
#   'dan',
#   'la',
#   'vélostat',
#   'epfl',
#   'httpstcoeituenfoax'],
#  ['act',
#   'global',
#   'think',
#   'campu',
#   'epflen',
#   'epfldur',
#   'martinvetterli',
#   'httpstco4vuyimvgj'],
#  ['student',
#   'epfl',
#   'unifr',
#   'design',
#   'selfsuffici',
#   'home',
#   'integr',
#   'solar',
#   'panel',
#   'good',
#   'luck',
#   'solardecathlon',
#   'httpstcocuixeajydh'],
#  ['scientist',
#   'epflen',
#   'abl',
#   'watch',
#   'human',
#   'brain',
#   'rewir',
#   'itself',
#   'adjust',
#   'advanc',
#   'prosthes',
#   'neurosci',
#   'medtech',
#   'digitalhealth',
#   'httpstco8staqsmknh'],
#  ['is',
#   'or',
#   'epfl',
#   'badcompani',
#   'day',
#   'p',
#   'httpstcoitndng8wsf',
#   'httpstcoxnufe4mmwc'],
#  ['measur',
#   'water',
#   'qualiti',
#   'snake',
#   'robot',
#   'biosensor',
#   'cool',
#   'work',
#   'dmfunil',
#   'jr',
#   'vd',
#   'meer',
#   'amp',
#   'epfl',
#   'ht',
#   'fpbock',
#   'httpstcovpzbekanay'],
#  ['water',
#   'surprisingli',
#   'order',
#   'surfac',
#   'nano',
#   'droplet',
#   'httpstcokxjjlgwmy5',
#   'epfl',
#   'httpstcoyjkjnlqnyw'],
#  ['ran',
#   'exutcae',
#   'student',
#   'gordon',
#   'research',
#   'conf',
#   'work',
#   'w',
#   'undergrad',
#   'satoshi',
#   'takahama',
#   'success',
#   'faculti',
#   'member',
#   'epfl',
#   'httpstcophsuxdc7hp'],
#  ['video',
#   'nicola',
#   'marzari',
#   'epflen',
#   'comput',
#   'discoveri',
#   '21st',
#   'centuri',
#   'pasc17',
#   'onlin',
#   'httpstcotfckevyktq',
#   'httpstcohttpdhck9w'],
#  ['after',
#   'jet',
#   'lag',
#   'forget',
#   'hk–chic',
#   'episod',
#   '6',
#   'chiccommun',
#   'epfl',
#   'voyag',
#   'hongkong',
#   'httpstco3lng5suuw8',
#   '…'],
#  ['it',
#   'tomorrow',
#   'swissedtechcollid',
#   'keep',
#   'eye',
#   'edtech',
#   'httpstcophz8wpvtn0'],
#  ['spaceship', 'epfl', 'lausann', 'httpstcolb223yt804'],
#  ['top',
#   'architect',
#   'travail',
#   'de',
#   'fin',
#   'danné',
#   'exhibit',
#   'exposit',
#   'epfl',
#   'architectureschool',
#   'seoul',
#   'métro',
#   'line',
#   'proje…',
#   'httpstcozdvowdckrx',
#   'httpstcocmoowb3eh6'],
#  ['et',
#   'de',
#   'superpouvoir',
#   'de',
#   'bibliothécair',
#   'de',
#   'la',
#   'bcu',
#   'alor',
#   'httpstcojoyiuoroh'],
#  ['meet',
#   'ijspeert',
#   'lab',
#   'epflen',
#   'lab',
#   'pleurobot',
#   'live',
#   'see',
#   'whole',
#   'video',
#   'httpstcos0zduif3k2',
#   'httpstco1fgggsnrkl'],
#  ['pa',
#   'mal',
#   'le',
#   'soiréesbibliothèqu',
#   'au',
#   'rolexlearningcent',
#   'epfl',
#   '📚📝',
#   'httpstco8owqib0csc'],
#  ['construct',
#   'ml',
#   'poster',
#   'creativeai',
#   'musictech',
#   'nips2016',
#   'ai',
#   'httpstcoixjnhrirwi'],
#  ['we',
#   'look',
#   'forward',
#   'swiss',
#   'cytometri',
#   'meet',
#   'ecol',
#   'polytechniqu',
#   'fédérale',
#   'de',
#   'lausann',
#   '79',
#   'feb',
#   'drop',
#   'top',
#   'tip',
#   'streamlin',
#   'oper',
#   'research',
#   'facil',
#   'httpstco2bbtingzup',
#   'corefacil',
#   'roi',
#   'epfl',
#   'epflsv',
#   'swisscytometri',
#   'swisscytometri',
#   'httpstcolcs564yavr'],
#  ['watch',
#   'video',
#   'knight',
#   'support',
#   'flatearth',
#   'view',
#   'brjsa📀',
#   'augustepiccard',
#   'ericdubay',
#   '💡👉httpstcogz0y5vtrij',
#   'holyghostalic'],
#  ['some',
#   'nice',
#   'day',
#   '1',
#   'spheroid',
#   'violainese',
#   'lab',
#   'imag',
#   'size',
#   'cciliv',
#   'good',
#   'opportun',
#   'play',
#   'deconvolut',
#   'algorithm',
#   'deconvolutionlab2',
#   'httpstcootrxa96zfu',
#   'httpstcobkliewfcro'],
#  ['a',
#   'parametr',
#   'tool',
#   'evalu',
#   'environment',
#   'econom',
#   'feasibl',
#   'decentr',
#   'energi',
#   'system',
#   'httpstcomc2d0l1xrw'],
#  ['📆',
#   'our',
#   'spinoff',
#   'fhaptic',
#   'attend',
#   'erf2018',
#   '1315th',
#   'march',
#   'finland',
#   '▶️want',
#   'know',
#   'foldaway',
#   'haptic',
#   'httpstcovzvmpcj3hv',
#   'robot',
#   'virtualr',
#   'robot',
#   'joystick',
#   'vr',
#   'rrl',
#   'epfl',
#   'swissstartup',
#   'roboticist',
#   'haptic'],
#  ['“',
#   'strong',
#   'robust',
#   'neg',
#   'relat',
#   'length',
#   'titl',
#   'articl',
#   'scientif',
#   'qualiti',
#   '”',
#   'worri',
#   'moment',
#   'econom',
#   'articles…',
#   'httpstco5mf6xxcaih'],
#  ['after',
#   'year',
#   'reiter',
#   'safe',
#   'navig',
#   'popul',
#   'indoor',
#   'environ',
#   'mobil',
#   'robot',
#   'larg',
#   'solv',
#   'epfl',
#   '‘',
#   'alex',
#   'alahi',
#   'demonstr',
#   'safe',
#   'natur',
#   'normal',
#   'my',
#   'bad',
#   'a3forum',
#   'alexalahi'],
#  ['dieser',
#   'dr',
#   'michael',
#   'gonin',
#   'ist',
#   'wirklich',
#   'gut',
#   'er',
#   'bringt',
#   'geschicht',
#   'unternehmertum',
#   'und',
#   'sozial',
#   'verantwortung',
#   'zusammen',
#   'epfl',
#   'hybridesdenken',
#   'httpstcoboreqiexit'],
#  ['so',
#   'excit',
#   'see',
#   'epfl',
#   'among',
#   'inaugur',
#   'partner',
#   'gixedu',
#   'global',
#   'innov',
#   'exchang',
#   'w',
#   'uw',
#   'amp',
#   'tsinghuauni',
#   'httpstcoc9c96wee6b'],
#  ['fifel',
#   'panel',
#   '1012',
#   'prof',
#   'yunu',
#   'discuss',
#   'prof',
#   'f',
#   'vuill',
#   'epfl',
#   'cen',
#   'director',
#   'hrff',
#   'zurich',
#   'access',
#   'energi',
#   'human',
#   'right',
#   '15billion',
#   'peopl',
#   'still',
#   'access',
#   'electr',
#   'follow',
#   'day',
#   'prof',
#   'yunu',
#   '’',
#   'public',
#   'lectur',
#   'epfl',
#   'httpstcohxsovlrngb',
#   'via',
#   'youtub',
#   'httpstco04a2xijk2f'],
#  ['thank',
#   'next',
#   'plane',
#   'also',
#   'delay',
#   'jenmccutcheon',
#   'also',
#   'got',
#   'secur',
#   'plane',
#   'i',
#   'also',
#   'met',
#   'henrik',
#   'epfl',
#   'shortli',
#   'way',
#   'next',
#   'leg',
#   'cape',
#   'town',
#   'halfway',
#   'point',
#   'antarctica',
#   'antarcticbas',
#   'polarfound'],
#  ['rx',
#   'solut',
#   'ct',
#   'system',
#   'ultratom',
#   'help',
#   'read',
#   'book',
#   'without',
#   'open',
#   'read',
#   'unread',
#   'scienc',
#   'ct',
#   '3d',
#   'tomographi',
#   'lemondefr',
#   'epfl',
#   'epflen',
#   'more',
#   'inform',
#   'httpstco0whox0aktr'],
#  ['new',
#   'evid',
#   'dark',
#   'matter',
#   'make',
#   'even',
#   'exot',
#   'httpstco5tmqyjekih',
#   'via',
#   'epflen',
#   'vdtech',
#   'research',
#   'httpstco9kyvtde4qa'],
#  ['dark',
#   'matter',
#   'even',
#   'darker',
#   'thought',
#   'httpstcoztotop5a2o',
#   'oscienc',
#   'epflen',
#   'darkmatt',
#   'hubbl',
#   'astronomi',
#   'httpstcoem60qbahti'],
#  ['accord',
#   'epfl',
#   'studi',
#   'butterfli',
#   'live',
#   'urban',
#   'area',
#   'face',
#   'threat',
#   'consanguin',
#   'potenti',
#   'extinct',
#   'httpstco9kcj2kfaek'],
#  ['ultrafast',
#   'processor',
#   'thank',
#   'plasmon',
#   'httpstcoihd8nqh1u9',
#   'epflen',
#   'quantum',
#   'nanostructur',
#   'httpstcoae68flyvs5'],
#  ['fantast',
#   'multimedia',
#   'present',
#   'solv',
#   'paralysi',
#   'epflen',
#   'gregoir',
#   'courtin',
#   'great',
#   'see',
#   '1st',
#   'human',
#   'step',
#   'wysssupport',
#   'ins2017'],
#  ['instal',
#   'metal',
#   'iterlik',
#   'first',
#   'wall',
#   'fusion',
#   'reactor',
#   'jet',
#   'made',
#   'difficult',
#   'oper',
#   'httpstco0ryra559n0',
#   'epfl'],
#  ['chrlovi',
#   'hopitauxunig',
#   'unigenew',
#   'planetesant',
#   'epfl',
#   'career',
#   'need',
#   'strong',
#   'health',
#   'informat',
#   'train',
#   'use',
#   'standard'],
#  ['new',
#   'perovskit',
#   'next',
#   'gener',
#   'data',
#   'storag',
#   'httpstcodofvlxov71',
#   'epfl',
#   'epflen',
#   'energystorag'],
#  ['franceia',
#   'aud',
#   'billard',
#   'professeur',
#   'epfl',
#   'lintellig',
#   'comprendr',
#   'pour',
#   'sadapt',
#   'besoin',
#   'de',
#   'la',
#   'connaiss',
#   'apprendr',
#   'et',
#   'extrapol',
#   'httpstcosnrtupk8po'],
#  ['ehmicrobiomes2017',
#   'prof',
#   'tom',
#   'battin',
#   'epflen',
#   'present',
#   'ocean',
#   'stream',
#   'ntusg',
#   'natureconf',
#   'naturenpj',
#   'assoc',
#   'ed',
#   'httpstco6f6pmtukz2'],
#  ['great',
#   'talk',
#   'amp',
#   'discuss',
#   'mindmazesa',
#   'ceo',
#   'tejtadi',
#   'amp',
#   'venturelabch',
#   'jordimontserrat',
#   'champsnight',
#   'epflen',
#   'vdtech',
#   'httpstcown528crdwt'],
#  ['the',
#   'timeshigh',
#   'rank',
#   'eth',
#   'epflen',
#   '1',
#   '2',
#   'intern',
#   'univers',
#   '2017',
#   'swissunivers',
#   'higher',
#   'httpstcoyyfhsr2qsb',
#   'httpstcowvjrzxajgi'],
#  ['i',
#   'wonder',
#   'mani',
#   'innoc',
#   'peopl',
#   'swiss',
#   'polic',
#   'rape',
#   'amp',
#   'tortur',
#   '72',
#   'prison',
#   'popul',
#   'foreign',
#   'mani',
#   'tortur',
#   'confess'],
#  ['un',
#   'laboratoir',
#   'pour',
#   'sauver',
#   'l',
#   '’',
#   'architectur',
#   'du',
#   'xxe',
#   'siècl',
#   'epfl',
#   '24heuresch',
#   'lecorbusi',
#   'httpstcooeey3veeb4'],
#  ['drone',
#   'week',
#   '2',
#   'epfl',
#   'lausann',
#   'origamiinspir',
#   'vtol',
#   'cargo',
#   'drone',
#   'fold',
#   'protect',
#   'cage',
#   'fli',
#   'deliv',
#   'safe',
#   'httpstconz9kigfbn2'],
#  ['for',
#   'first',
#   'time',
#   'epfl',
#   'librari',
#   'take',
#   'part',
#   'love',
#   'data',
#   'week',
#   'find',
#   'program',
#   'detail',
#   'stay',
#   'tune',
#   'week',
#   'dedic',
#   'researchdata',
#   'opensci',
#   'lovedata18',
#   'httpstcochibnceiwj'],
#  ['the',
#   '1st',
#   'present',
#   'held',
#   'prof',
#   'dominiqueforay',
#   'evidencebas',
#   's3',
#   'futur',
#   'post2020🇪🇺rampi',
#   'polici',
#   'landscap',
#   'he',
#   'say',
#   'one',
#   's3',
#   'goal',
#   'find',
#   'new',
#   'combin',
#   'regionalspecif',
#   'capac',
#   'regionalspecif',
#   'opportun',
#   'epfl',
#   'epflen',
#   'httpstcosktacgrukw'],
#  ['financi',
#   'predict',
#   'appliedmlday',
#   'stefanotempesta',
#   'epflen',
#   'amld2018',
#   'machinelearn',
#   'futur',
#   'fintech',
#   'datasci',
#   'httpstcofclzitsweo'],
#  ['uefa', 'uefaeuro', 'anyway', 'epflen', 'student', 'enter', 'd'],
#  ['de',
#   'opportunité',
#   'à',
#   'saisir',
#   'le',
#   'technolog',
#   'développé',
#   'en',
#   'laboratoir',
#   'profit',
#   'aux',
#   'sportif',
#   'httpstcoqfzdfohgpp',
#   'via',
#   'epfl',
#   'httpstco5qiiwlrwqj'],
#  ['a',
#   'sion',
#   'construit',
#   'un',
#   'campu',
#   'denfer',
#   'hessovalai',
#   'thearkvalai',
#   'epfl',
#   'valai',
#   'vu',
#   'depui',
#   'esrofficiel',
#   'httpstcom4tvqnlcnm'],
#  ['sleep',
#   'neurosci',
#   'neurosci',
#   'scienc',
#   'healthi',
#   'mitochondria',
#   'could',
#   'stop',
#   'alzheim',
#   'httpstcoriozv4axxn',
#   'epfl'],
#  ['epfl',
#   'scientist',
#   'develop',
#   'selfheal',
#   'materi',
#   'inspir',
#   'plant',
#   'httpstcosiaunzx3f8',
#   'via',
#   'epflen',
#   'vdtech',
#   'httpstcoryqo5z3jhk'],
#  ['databas',
#   'clarifi',
#   'bottomup',
#   'design',
#   'cement',
#   'httpstcoebjlvalhzz',
#   'epfl'],
#  ['someon',
#   'explor',
#   'wikipedia',
#   'often',
#   'first',
#   'stop',
#   'start',
#   'search',
#   'inform',
#   'topic',
#   'even',
#   'dont',
#   'admit',
#   'httpstcoxwvnxyfunq'],
#  ['shape',
#   'futur',
#   'neuromodul',
#   'research',
#   'worldlead',
#   'scientist',
#   'regist',
#   'nm2',
#   'httpstcorbhltiqx8a',
#   'nm2conf',
#   'epfl',
#   'httpstcovnynwsdb9f'],
#  ['a',
#   'swiss',
#   'librari',
#   'revolution',
#   'concept',
#   'librari',
#   'httpstco00omllvto8',
#   'travel',
#   'epfl',
#   'traveltuesday',
#   'switzerland'],
#  ['thoma',
#   'knecht',
#   'ventureoffic',
#   'announc',
#   'award',
#   'ceremoni',
#   '2018',
#   'take',
#   'place',
#   'epfl',
#   'httpstconb3amxxo6z'],
#  ['for',
#   'space',
#   'enthusiast',
#   'epfl',
#   'offer',
#   'mooc',
#   'space',
#   'mission',
#   'design',
#   'oper',
#   'w',
#   'astronaut',
#   'claud',
#   'nicolli',
#   'httpstcoxfn5abbrit'],
#  ['what',
#   'intern',
#   'univers',
#   'world',
#   'ethen',
#   'epflen',
#   'lead',
#   'timeshigh',
#   'report',
#   'httpstco8hh2xacpdn',
#   'httpstcoxaapgicva3'],
#  ['immersiatvpart',
#   'futur',
#   'european',
#   'media',
#   'accord',
#   'techeu',
#   'dsmeu',
#   'eucommiss',
#   'research',
#   'innov',
#   'httpstcopeme43mdfn'],
#  ['your',
#   'mozz',
#   'drop',
#   'githubeduc',
#   '✨',
#   'epfl',
#   'mooc',
#   'factori',
#   '🎥',
#   'httpstcozmvfhhyhli'],
#  ['amin',
#   'studi',
#   'epflen',
#   'thought',
#   'famili',
#   'thi',
#   'mad',
#   'stop',
#   'httpstconhsvjdpa0w'],
#  ['how',
#   'becom',
#   'growth',
#   'hacker',
#   'great',
#   'meet',
#   'today',
#   'besmart',
#   'educ',
#   'beobsess',
#   'passion',
#   'technolog',
#   'swissedtechcollid',
#   'innovaud',
#   'epfl',
#   'masschallengech',
#   'forbesunder30',
#   'swissnexindia',
#   'unicef',
#   'httpstcob4qwcq4hda'],
#  ['j',
#   '’',
#   'aimerai',
#   'just',
#   'vou',
#   'donnez',
#   'une',
#   'inform',
#   'japan',
#   'impact',
#   'aura',
#   'lieux',
#   'le',
#   '17',
#   'et',
#   '18',
#   'fev',
#   '2018',
#   'japanimpact',
#   'httpstcojkukx2ke3r',
#   'httpstcons9d2v1vba',
#   'epfl',
#   'lausann',
#   'nobillag',
#   'neinzunobillag',
#   'rt',
#   'srg',
#   'rtsi'],
#  ['envirobot',
#   'eel',
#   'epfl',
#   'locat',
#   'sourc',
#   'water',
#   'pollut',
#   'switzerland',
#   'httpstcou1ottqcvlu'],
#  ['invest', 'invest', 'invest', 'research', 'httpstcoh3t8onsbo'],
#  ['have', 'great', 'week', 'httpstcojs4tewsguh'],
#  ['first',
#   'workshop',
#   'vleadersfintech',
#   'curti',
#   'giesenhow',
#   'pitch',
#   'new',
#   'york',
#   'dgtswitzerland',
#   'postfin',
#   'innovaud',
#   'sfsch',
#   'epflen',
#   'httpstcoa0fsbkkmwn'],
#  ['alzheim',
#   'la',
#   'vitamin',
#   'b3',
#   'et',
#   'un',
#   'antibiotiqu',
#   'amélior',
#   'la',
#   'santé',
#   'de',
#   'mitochondri',
#   'et',
#   'réduisent',
#   'ainsi',
#   'le',
#   'dommag',
#   'de',
#   'la',
#   'maladi',
#   'sur',
#   'modèl',
#   'anim',
#   'httpstcogp8mbyxeqt',
#   'via',
#   'epfl',
#   'httpstcoxwnsg7vcei'],
#  ['⚠️caution⚠️',
#   'critic',
#   'avalanch',
#   'danger',
#   'swiss',
#   '45',
#   'also',
#   'french',
#   '55',
#   'alp',
#   'due',
#   'heavi',
#   'snowfal',
#   'strong',
#   'wind',
#   'read',
#   'full',
#   'bulletin',
#   'httpstcokbirk356nn',
#   'snow',
#   'neig',
#   'snowscienc',
#   'slf',
#   'avalanch',
#   'danger',
#   'swiss',
#   'franc',
#   'alp',
#   'epfl',
#   'httpstcolyyuk5w3yp'],
#  ['highli', 'appreci', 'work', 'sensor', 'httpstcopybcdhk9rp'],
#  ['danish',
#   'school',
#   'instal',
#   'world',
#   '’',
#   'largest',
#   'solar',
#   'façad',
#   'httpstcoi7gsr6qw1m',
#   'epflen',
#   'copenhagen',
#   'switzerland',
#   'clean',
#   'energi',
#   'green',
#   'httpstco5mvdxw3ofn'],
#  ['trace',
#   'possibl',
#   'martian',
#   'biolog',
#   'activ',
#   'insid',
#   'meteorit',
#   'httpstcopzu3ng1vmp',
#   'oscienc',
#   'epflen',
#   'mar',
#   'httpstco4l1kod6rgm'],
#  ['present',
#   'last',
#   'vleaderslifesci',
#   '2017',
#   'today',
#   'mattia',
#   'larsson',
#   'founder',
#   'epfl',
#   'startup',
#   'suincol',
#   'httpstcohdf05qrhiu',
#   'httpstconhpahrisgp'],
#  ['a',
#   'selfsuffici',
#   'home',
#   'solarpanel',
#   'instal',
#   'facad',
#   'httpstcodrtxjxjdzd',
#   'epflen'],
#  ['seednight',
#   'tomorrow',
#   'epflen',
#   'come',
#   'see',
#   'pbampb',
#   'innov',
#   'aesthet',
#   'amp',
#   'antiag',
#   'medicin',
#   'httpstcoun7wlrhkna',
#   'vdtech',
#   'httpstcokmp1urxpuo'],
#  ['le',
#   'polycopié',
#   'epfl',
#   'support',
#   'de',
#   'cour',
#   'conçu',
#   'par',
#   'le',
#   'prof',
#   'sont',
#   'dispon',
#   'à',
#   'la',
#   'bibliothèqu',
#   'et',
#   'emprunt',
#   'httpstcobanevqtrxf',
#   'httpstcocfigqtyncp'],
#  ['food',
#   'one',
#   'largest',
#   'industri',
#   'world',
#   'enorm',
#   'potenti',
#   'new',
#   'model',
#   'great',
#   'challeng',
#   'openfood',
#   'hackday',
#   'epfl',
#   'marcelsalath',
#   'httpstco2sdcrepbwj'],
#  ['epflen',
#   'scientist',
#   'develop',
#   'novel',
#   'dnasequenc',
#   'techniqu',
#   'suitabl',
#   'dnabind',
#   'protein',
#   'character',
#   'httpstcoyx312g9r4i',
#   'httpstcoqygdqtlvgt'],
#  ['epfl',
#   'retrouvez',
#   'votr',
#   '1er',
#   'tweet',
#   'sélectionné',
#   'par',
#   'limport',
#   'httpstcob2tct924cp'],
#  ['le',
#   'cour',
#   'finiss',
#   'aujourdhui',
#   'et',
#   'je',
#   'souhait',
#   'de',
#   'bonn',
#   'révision',
#   'aux',
#   '7047',
#   'étudiant',
#   'inscrit',
#   'aux',
#   'examen',
#   'agepoli',
#   'epfl',
#   'epflen',
#   'httpstcormj8q7zfkl'],
#  ['environn',
#   'un',
#   'marché',
#   'en',
#   'plein',
#   'croissanc',
#   'httpstcothtcylrmtn',
#   'avec',
#   'philipp',
#   'thalmann',
#   'epfl'],
#  ['cousinjimmy2',
#   'i',
#   'made',
#   'seri',
#   'slide',
#   'tell',
#   'stori',
#   'tortur',
#   'amp',
#   'sexualharass',
#   'sexualabus',
#   'swiss',
#   'polic',
#   'inspector',
#   'fabienfontannaz',
#   'public',
#   'prosecitor',
#   'fredericgisl',
#   'dr',
#   'law',
#   'unifr',
#   'epfl',
#   'httpstcohwpuuidyd5',
#   'httpstcodftdrcetrl'],
#  ['new',
#   'version',
#   'epfl',
#   'mooc',
#   'plasma',
#   'avail',
#   'time',
#   'edxonlin',
#   'follow',
#   'lectur',
#   'plasma',
#   'medicin',
#   'superconduct',
#   'fusion',
#   'laserplasma',
#   'interact',
#   'taught',
#   'expert',
#   'sorbonneuniv',
#   'amp',
#   'polytechniqu',
#   'httpstcojgfkumdvyi'],
#  ['d',
#   'deeplearn',
#   'cours',
#   'epfl',
#   'machinelearn',
#   'deeplearn',
#   'ann',
#   'ai',
#   'ia',
#   'machinelearn',
#   'bigdata',
#   'datasci',
#   'httpstcontplsnrafn'],
#  ['mooc',
#   'household',
#   'level',
#   'water',
#   'treatment',
#   'method',
#   'amp',
#   'success',
#   'implement',
#   'strategi',
#   'assess',
#   'impact',
#   'thereof',
#   'part',
#   '“',
#   'sanit',
#   'water',
#   'amp',
#   'solid',
#   'wast',
#   'develop',
#   '”',
#   'mooc',
#   'seri',
#   'free',
#   'run',
#   'continu',
#   'httpstco2ibzrspr4b',
#   'eawagresearch',
#   'epfl',
#   'httpstcobh4l44zsmn'],
#  ['da',
#   'neue',
#   'programm',
#   'für',
#   'praxisorientiert',
#   'eawag',
#   'kurs',
#   'peak',
#   'ist',
#   'jetzt',
#   'onlin',
#   'httpstco6houuycwab',
#   'der',
#   'nächste',
#   'kur',
#   '«',
#   'relevé',
#   'écomorphologiqu',
#   'et',
#   'évaluat',
#   'de',
#   'rive',
#   'lacustr',
#   '»',
#   'findet',
#   '7',
#   'februar',
#   'der',
#   'epfl',
#   'statt',
#   'httpstconw0imihxpb',
#   'httpstcorf4pslggab'],
#  ['rappel',
#   'la',
#   'bibliothequ',
#   'epfl',
#   'recherch',
#   'encor',
#   'de',
#   'étudiant',
#   'motivé',
#   'pour',
#   'aider',
#   'à',
#   'organis',
#   'une',
#   'silentparti',
#   'et',
#   'fair',
#   'danser',
#   'le',
#   'rolexlearningcent',
#   'en',
#   '2018',
#   '🎧',
#   'silentdisco',
#   'epfl',
#   'merci',
#   'à',
#   'ceux',
#   'qui',
#   'se',
#   'sont',
#   'déjà',
#   'manifesté',
#   'et',
#   'bon',
#   'weekend',
#   'à',
#   'tou',
#   'httpstcosx2wyozlpj'],
#  ['develop',
#   'robot',
#   'walk',
#   'natur',
#   'httpstcoa1y1stv0lb',
#   'robot',
#   'epflen',
#   'biorobot',
#   'httpstcooe6jhuulm9'],
#  ['smileseq',
#   'identifi',
#   'bind',
#   'motif',
#   'singl',
#   'dimer',
#   'transcript',
#   'factor',
#   'ng',
#   'slim',
#   'epflen',
#   'httpstcogdce6nyj6i'],
#  ['epfl',
#   'expans',
#   'toward',
#   'green',
#   'chemistri',
#   'alpin',
#   'extrem',
#   'environ',
#   'httpstcoou16d36it9',
#   'epfl',
#   'httpstcomgstnsl32x'],
#  ['bell',
#   'leçon',
#   'de',
#   'technologi',
#   'dan',
#   'rtscqfd',
#   'avec',
#   'lexosquelett',
#   'twiiceoffici',
#   'testé',
#   'par',
#   'silk',
#   'pan',
#   'httpstco4uidxckvaq',
#   'rtscqfd',
#   'epfl'],
#  ['portabl',
#   'probe',
#   'hunt',
#   'cancer',
#   'cell',
#   'surgeri',
#   'httpstco3qhw8vh9il',
#   'via',
#   'epflen',
#   'httpstcolmaahz5ybr'],
#  ['noir',
#   'cest',
#   'noir',
#   'dite',
#   'vou',
#   'artlab',
#   'pierresoulag',
#   'epfl',
#   'epflcultur',
#   'epfl',
#   'neig',
#   'expo',
#   'httpstcorolwlcnfew'],
#  ['6',
#   'point',
#   'last',
#   'night',
#   'blue',
#   'epfl',
#   '20',
#   'amp',
#   '120',
#   'win',
#   'whipton',
#   'st',
#   'nichola',
#   'c',
#   '⚽️🔵'],
#  ['learn',
#   'adapt',
#   'differ',
#   'materi',
#   'tempor',
#   'biomedia',
#   'colab',
#   'workshop',
#   'epfl',
#   'hackuarium',
#   'osspari',
#   'httpstcorpg0ytemsu'],
#  ['epfl',
#   'embark',
#   'new',
#   'horizon',
#   'continu',
#   'educ',
#   'httpstcoos7mfkm1eh',
#   'vdtech',
#   'cc',
#   'epflen',
#   'logitech',
#   'httpstcod2oi9inptx'],
#  ['epfl',
#   'cnbi',
#   '2016',
#   'highlights1212',
#   'our',
#   'team',
#   'first',
#   'ever',
#   'cybathlon',
#   'bci',
#   'race',
#   'httpstcotavirrwpkc',
#   'happi',
#   '2017',
#   'everybodi',
#   'httpstcoqzv4saerzq'],
#  ['im',
#   'organ',
#   'confer',
#   'neuromodul',
#   'travel',
#   'award',
#   'avail',
#   'httpstcorbhltiqx8a',
#   'nm2conf',
#   'bluebrainpjt',
#   'epflen',
#   'httpstcokggcynsmwa'],
#  ['last',
#   'day',
#   'regist',
#   'next',
#   'startup',
#   'champion',
#   'event',
#   'the',
#   'multipl',
#   'live',
#   'entrepreneur',
#   'epfl',
#   'httpstcoyq7umjzvin',
#   'suchamp',
#   'httpstcoihihujkfek'],
#  ['aigs2017',
#   'ia',
#   'ai',
#   'interview',
#   'marcelsalath',
#   'epfl',
#   'digitalhealth',
#   'epidemiolog',
#   'campusbiotech',
#   'limport',
#   'de',
#   'alert',
#   'précose',
#   'resumé',
#   'httpstcoarbz9t2dzx'],
#  ['lepfl',
#   'crée',
#   'un',
#   'centr',
#   'pour',
#   'la',
#   'cybersécurité',
#   'avec',
#   'directeur',
#   'académiqu',
#   'du',
#   'centr',
#   'jeanpierr',
#   'hubaux',
#   'digitaltrust',
#   'httpstcoqkysnjcskw',
#   'secur',
#   'httpstcorkcvwo6k2p'],
#  ['trè',
#   'bel',
#   'exempl',
#   'dune',
#   'collabor',
#   'interdisciplinair',
#   'quand',
#   'le',
#   'scienc',
#   'humain',
#   'ont',
#   'recour',
#   'à',
#   'la',
#   'physiqu',
#   'httpstcoehgkchyud6',
#   'epfl',
#   'frederickaplan',
#   'archivch',
#   'archimag'],
#  ['new',
#   'perovskit',
#   'age',
#   'measur',
#   'offer',
#   'standard',
#   'epfl',
#   'pv',
#   'tech',
#   'switzerland',
#   'httpstco0acwalws6q'],
#  ['caution',
#   '⚠️',
#   'extrem',
#   'avalanch',
#   'danger',
#   'walli',
#   'french',
#   'massif',
#   'savoi',
#   'due',
#   'heavi',
#   'snowfal',
#   'full',
#   'belletin',
#   'httpstcokbirk356nn',
#   'avalanch',
#   'snow',
#   'snowscienc',
#   'slf',
#   'extrem',
#   'danger',
#   'hazard',
#   'caution',
#   'prudenc',
#   'neig',
#   'risqu',
#   'switzerland',
#   'franc',
#   'epfl',
#   'httpstcocujsqv4kfd'],
#  ['standard', 'perovskit', 'age', 'measur', 'httpstcoj25lllqmto', 'epflen'],
#  ['kevinschawinski',
#   'influenc',
#   'prof',
#   'ethdomain',
#   'congrat',
#   'epflen',
#   'strong',
#   'top',
#   'ten',
#   'httpstcoyrndlr6zh0',
#   'httpstco7zgbr0eotc'],
#  ['die',
#   'onlineschul',
#   'der',
#   'epfl',
#   'hat',
#   'mit',
#   'dem',
#   '«',
#   'certif',
#   'open',
#   'studi',
#   '»',
#   'einen',
#   'neuen',
#   'akademischen',
#   'diplomtypu',
#   'in',
#   'leben',
#   'gerufen',
#   'epfl',
#   'httpstcowzvufmyxid',
#   'weiterbildung',
#   'diplom',
#   'co'],
#  ['readi',
#   'coltran',
#   'enoch',
#   'pratt',
#   'loch',
#   'raven',
#   'branch',
#   'free',
#   'show',
#   'kudo',
#   'weaafm',
#   'tip',
#   'httpstco6jehtk8y7i',
#   'epfl'],
#  ['mani',
#   'congrat',
#   'stew',
#   'great',
#   'alumni',
#   'epfl',
#   'and',
#   'good',
#   'luck',
#   'lavieparisienn',
#   'httpstcosj0n2cdqw4'],
#  ['today',
#   'wit',
#   'graduat',
#   '994',
#   'new',
#   'epfl',
#   'ambassador',
#   'congratul',
#   'student',
#   'epfl',
#   'magistrale2017',
#   'epflev',
#   'httpstco3jd6ff6a9z'],
#  ['wonder',
#   'teashop',
#   'nyon',
#   'httpstcoeozeypyi68',
#   'lecercleduth',
#   'also',
#   'fb',
#   'unil',
#   'epfl',
#   'unigeen',
#   'lifeinnyon',
#   'mynyonregion',
#   'lemantourism'],
#  ['significantli',
#   'speed',
#   '3d',
#   'stem',
#   'imag',
#   'nanostructur',
#   'emad',
#   'oveisi',
#   'colleagu',
#   'epfl',
#   'httpstcofqknaemwgu'],
#  ['cyclobiblio',
#   'epfl',
#   'espac',
#   'dexpo',
#   'au',
#   'learn',
#   'center',
#   'httpstcohyakwdur3o'],
#  ['muslimban',
#   'amin',
#   'karbasi',
#   'professor',
#   'yale',
#   'univers',
#   'wife',
#   'daughter',
#   'stuck',
#   'outsid',
#   'us',
#   'httpstcorqftymktm9'],
#  ['bscampmast',
#   'student',
#   'appli',
#   'nanotechnolog',
#   'summerschool',
#   'grenobleinp',
#   'w',
#   'partner',
#   'epflen',
#   'politonew',
#   'httpstco8jduui0oiu',
#   'httpstcozsy1cshedk'],
#  ['la',
#   'bibliothèqu',
#   'de',
#   'l',
#   '’',
#   'epfl',
#   'recherch',
#   'de',
#   'étudiant',
#   'epfl',
#   'motivé',
#   'pour',
#   'aider',
#   'à',
#   'organis',
#   'une',
#   'silentparti',
#   'et',
#   'fair',
#   'danser',
#   'le',
#   'rolexlearningcent',
#   'en',
#   '2018',
#   '🎧',
#   'vou',
#   'ête',
#   'intéressé',
#   'par',
#   'une',
#   'collabor',
#   'avec',
#   'nou',
#   'écrivezn',
#   'avant',
#   'le',
#   '2101',
#   'à',
#   'l',
#   '’',
#   'adress',
#   'auroregranvalepflch',
#   '📧',
#   'httpstcogjfgwn1gcq'],
#  ['is',
#   'uneth',
#   'build',
#   'ai',
#   'human',
#   'trust',
#   'much',
#   'ask',
#   'j2bryson',
#   'aihealth',
#   'swsx',
#   'sxswiss'],
#  ['rlerigni',
#   'sneedit',
#   'désolé',
#   'je',
#   'sui',
#   'jurist',
#   'je',
#   'ne',
#   'connai',
#   'pa',
#   'la',
#   'norm',
#   'iso',
#   '690'],
#  ['regist',
#   'train',
#   'write',
#   'success',
#   'h2020',
#   'propos',
#   '2',
#   'februari',
#   'zurich',
#   'httpstco4opdwrqfn8',
#   'heigvd',
#   'hesso',
#   'hessovalai',
#   'bfhhesb',
#   'zhaw',
#   'uzhnewsen',
#   'ethen',
#   'dgtswitzerland',
#   'venturelabch',
#   'fsrmch',
#   'unifr',
#   'swisseuresearch',
#   'snfch',
#   'sbfich',
#   'epflpark',
#   'epflen',
#   'httpstco0wb6ae4gox'],
#  ['new',
#   'report',
#   'risk',
#   'misus',
#   'life',
#   'scienc',
#   'research',
#   'httpstco6haoskjtmz',
#   'epfl',
#   'scnatch',
#   'httpstcovmkww0q2gq'],
#  ['«',
#   'la',
#   'photographi',
#   'darchiv',
#   'à',
#   'lâge',
#   'numériqu',
#   '»',
#   'bientôt',
#   'à',
#   'sa',
#   '3ème',
#   'édition',
#   'au',
#   'tessin',
#   'supsi',
#   'campu',
#   'trevano',
#   '9',
#   'avril4',
#   'mai',
#   '2018',
#   'epfl',
#   'epflenac',
#   'httpstcop0ir0pift3'],
#  ['we',
#   'way',
#   'first',
#   'swisscytometri',
#   'meet',
#   'epfl',
#   'lausann',
#   'httpstcogahnnos8eu',
#   'lhwstratocor',
#   'scm2018',
#   'corefacil',
#   'cytometri',
#   'flowcytometri',
#   'winterwonderland'],
#  ['what', 'httpstcoruvegs5egz'],
#  ['une',
#   'futur',
#   'ingénieur',
#   'expliqu',
#   'son',
#   'projet',
#   'epfl',
#   'hessovalai',
#   'httpstcolbd4stauna'],
#  ['two',
#   'compani',
#   'come',
#   '3d',
#   'map',
#   'mapkit',
#   'httpstco5hwwdcahxr',
#   'via',
#   'epflen',
#   'vdtech',
#   'httpstco6yp1ywa7ww'],
#  ['paus',
#   'déjeuner',
#   'moment',
#   'de',
#   'convivialité',
#   'en',
#   'plein',
#   'coeur',
#   'de',
#   'portivechju',
#   'avant',
#   'de',
#   'reprendr',
#   'le',
#   'travaux',
#   'de',
#   'lag',
#   'de',
#   'associ',
#   'de',
#   'epfl',
#   'httpstconzhkfztpx'],
#  ['quand',
#   'le',
#   '«',
#   'deep',
#   'learn',
#   '»',
#   'confond',
#   'une',
#   'cafetièr',
#   'avec',
#   'un',
#   'cobra',
#   'httpstcod7isvdvpnf',
#   'epfl',
#   'robot'],
#  ['rueeggthurgau',
#   'ewzenergi',
#   'mwayonlin',
#   'fairpowerch',
#   'ein',
#   'stimmungsbild',
#   'für',
#   'marco',
#   'rüegg',
#   '😉',
#   'tesla',
#   'park',
#   'epfl',
#   'httpstcot31ekfpq93'],
#  ['art',
#   'scienc',
#   'collis',
#   'a',
#   'present',
#   'art',
#   'resid',
#   'cern',
#   'yunchul',
#   'kim',
#   'helga',
#   'timko',
#   'epfl',
#   'gt',
#   'httpstcogt73oaevoh'],
#  ['anticanc',
#   'drug',
#   'get',
#   'boost',
#   'combin',
#   'antirheumat',
#   'epflen',
#   'ntusg',
#   'naturecomm',
#   'via',
#   'eurekalert',
#   'httpstconr6udhtjm'],
#  ['ypsome',
#   'first',
#   'industri',
#   'partner',
#   '“',
#   '5g',
#   'switzerland',
#   '”',
#   'swisscomm',
#   'ericsson',
#   'epfl',
#   'httpstco6nixgyxgbx'],
#  ['philipp',
#   'jovanov',
#   'daeinar',
#   'cryptosecur',
#   'research',
#   'epfl',
#   'give',
#   'talk',
#   'dotsecurityio',
#   'httpstcob1rcngnblz',
#   'httpstcoiklrksjqn5'],
#  ['epflen', 'avail', 'platform', 'edx'],
#  ['if',
#   'dont',
#   'know',
#   'epfl',
#   'stanford',
#   'switzerland',
#   'say',
#   'ukni',
#   'texa',
#   'sxsw',
#   'swissnexsf',
#   'epflen',
#   'httpstcoc8ssuixmmg'],
#  ['roboreptil',
#   'spi',
#   'fleshandblood',
#   'counterpart',
#   'httpstcocbwparmemb',
#   'bbc',
#   'epfl'],
#  ['an',
#   'effect',
#   'lowcost',
#   'solut',
#   'store',
#   'solarenergi',
#   'epfl',
#   'httpstcobszu1pc7yk',
#   'via',
#   'technologisteu',
#   'httpstcoqklwlqjifd'],
#  ['the',
#   'latest',
#   'dhum',
#   'carlo',
#   'httpstco39tyluij9i',
#   'thank',
#   'epfl',
#   'hackdisrupt'],
#  ['discov',
#   'httpstcodgxoj2dafk',
#   'adrian',
#   'holzer',
#   'epflen',
#   'dh',
#   'pedagog',
#   'day',
#   'unil',
#   'ladhul',
#   'dariahteach',
#   'httpstcocgupoky9b'],
#  ['intern', 'rank', 'eth', 'epfl', 'top', 'institut'],
#  ['music',
#   'sphere',
#   'httpstcoxwoypkslri',
#   'aristotl',
#   'say',
#   'born',
#   'hear',
#   'nois',
#   'without',
#   'silenc',
#   'compar',
#   'medit',
#   'music',
#   'return'],
#  ['call',
#   'edtech',
#   'startup',
#   'get',
#   'fund',
#   'mentor',
#   'amp',
#   'epflen',
#   'appli',
#   'juli',
#   '10',
#   'httpstcosraxlq5vc',
#   'ksacceler',
#   'edtechaccelch',
#   'httpstcoynvyv7enuk'],
#  ['we',
#   'happi',
#   'prof',
#   'thoma',
#   'nevian',
#   'unibern',
#   'deliv',
#   'final',
#   'lectur',
#   'afternoon',
#   'session',
#   'sept',
#   '18',
#   'nm2conf',
#   'httpstcosnvhxo1qgg'],
#  ['actuallywork',
#   'they',
#   'dont',
#   'call',
#   'funprog',
#   'noth',
#   'p',
#   'httpstcolqtqqyt5mx'],
#  ['femtoprint',
#   '18th',
#   'cmi',
#   'annual',
#   'review',
#   'meet',
#   'lausann',
#   'epfl',
#   'epflen',
#   'present',
#   'femtoprint®',
#   'technolog',
#   '3dprint',
#   'glass',
#   'httpstcocjnak2wc0p'],
#  ['advanc',
#   'digit',
#   'singlephoton',
#   'detector',
#   'pet',
#   'dr',
#   'claudio',
#   'bruschini',
#   'epfl',
#   'digitalimag',
#   'httpstcos3j7vxdgy9'],
#  ['jordi',
#   'montserrat',
#   'venturelabch',
#   'talk',
#   'epflen',
#   'champsnight',
#   'httpstcoiewa0fhu09'],
#  ['the',
#   'protein',
#   'domest',
#   'genom',
#   'httpstconpgbukjhbl',
#   'via',
#   'epflen',
#   'vdtech',
#   'httpstcoit0sbqlkqc'],
#  ['learn',
#   'use',
#   'technolog',
#   'innov',
#   'tool',
#   'fight',
#   'poverti',
#   'enabl',
#   'sustain',
#   'develop',
#   'epfl',
#   'httpstcomrcygxna6g'],
#  ['marcabraham',
#   'start',
#   'ignobel',
#   'award',
#   'tour',
#   'show',
#   'improbresearch',
#   'epfl',
#   'httpstcopoi6gl8iyv'],
#  ['julio',
#   'salgado',
#   'born',
#   'learn',
#   'amp',
#   'teach',
#   'httpstcoggjxqokinp',
#   'stori',
#   'via',
#   'epfl',
#   'ibmresearch',
#   'superglaz',
#   'theworldin',
#   'function'],
#  ['the',
#   'latest',
#   'the',
#   'architectur',
#   'free',
#   'press',
#   'httpstcotlieahzlsd',
#   'thank',
#   'divisar',
#   'jorgensundberg',
#   'epfl',
#   'interiordesign'],
#  ['encourag',
#   'carinadjey',
#   'edacyhq',
#   'lancement',
#   'programm',
#   'fast',
#   'format',
#   'codeur',
#   'dakar',
#   'espdakar',
#   'ucadseneg',
#   'epfl',
#   'code',
#   'africangeek',
#   'mooc',
#   'httpstcok7ndmjyqbi'],
#  ['retina',
#   'project',
#   'nice',
#   'intel',
#   'made',
#   'smart',
#   'glass',
#   'look',
#   'normal',
#   'httpstcojtnnxayhrl',
#   'via',
#   'verg'],
#  ['savmap',
#   'namibian',
#   'semiarid',
#   'savanna',
#   'imag',
#   'avail',
#   'analysi',
#   'httpstco5t4as0uei1',
#   'heluc',
#   'sdscdatasci',
#   'datajamday',
#   'opendata',
#   'httpstcovhf2qdgetx'],
#  ['let',
#   'real',
#   'no',
#   'one',
#   'read',
#   'internet',
#   'privaci',
#   'polici',
#   'thi',
#   'ai',
#   'interpret',
#   'inscrut',
#   'legales',
#   'help',
#   'becom',
#   'inform',
#   'user',
#   'httpstcoe2dcsoafrj'],
#  ['iciq',
#   'lead',
#   'aleaf',
#   'collabor',
#   'project',
#   'award',
#   '€8m',
#   'eucommiss',
#   'toward',
#   'artifici',
#   'leaf',
#   'httpstcot9zid3kv0c',
#   'httpstco0kflwez4eq'],
#  ['offici',
#   'ceremoni',
#   'nobelpr',
#   'winner',
#   'jacqu',
#   'dubochet',
#   'unil',
#   'presenc',
#   'br',
#   'guy',
#   'parmelin',
#   'opensci',
#   'societi',
#   'rabelai',
#   'epfl',
#   'epflen',
#   'epflev',
#   'httpstco8hjddrifxi'],
#  ['bike', 'night', 'epflcampu', 'epfl', 'httpstcont7v9hkz3o'],
#  ['ericdubay',
#   'valentina',
#   'madonna',
#   'fakepussi',
#   'realbaphomet',
#   'kingconrad',
#   'baychimokin',
#   'tortur',
#   'cheat',
#   '👹',
#   '👉httpstcowgalji7h0g'],
#  ['dedux',
#   'verg',
#   'der',
#   'miniprojektor',
#   'stammt',
#   'übrigen',
#   'von',
#   'lemoptix',
#   'einem',
#   'epfl',
#   '🇨🇭',
#   'spinoff',
#   'dass',
#   'intel',
#   '2015',
#   'übernommen',
#   'hat',
#   'innov',
#   'ar',
#   'venturelabch',
#   'swissnexsf',
#   'swissnexboston'],
#  ['a',
#   'step',
#   'forward',
#   'target',
#   'cancer',
#   'cell',
#   'measur',
#   'electr',
#   'current',
#   'httpstcoihyjn6az2i',
#   'via',
#   'epflen',
#   'vdtech',
#   'httpstcop91qrjk7zg'],
#  ['notr',
#   'conférenc',
#   'au',
#   'musé',
#   '’',
#   'art',
#   'et',
#   '’',
#   'histoir',
#   'à',
#   'genèv',
#   'aura',
#   'lieu',
#   'demain',
#   'mardi',
#   '3001',
#   'à',
#   '10h',
#   'mahgenev',
#   'epfl',
#   'unosat',
#   'venez',
#   'nombreux',
#   'patrimoin',
#   'numériqu',
#   'drone',
#   'innov',
#   'plu',
#   '’',
#   'info',
#   'httpstconjovod2dsn',
#   'amp',
#   'découvrez',
#   'un',
#   'articl',
#   'httpstcosj1zr4xd52',
#   'du',
#   'bilanmagazin',
#   'httpstcoaodxrekih3'],
#  ['reportag',
#   'sur',
#   'tf1lejt',
#   'le',
#   'étudiant',
#   'françai',
#   'se',
#   'tournent',
#   'davantag',
#   'ver',
#   'la',
#   'suiss',
#   'pour',
#   'leur',
#   'format',
#   'professionnel',
#   'lausann',
#   'httpstcotjqhmyuz6i',
#   'ehlnew',
#   'epfl',
#   'httpstcouauwsml5or'],
#  ['a',
#   'warm',
#   'thank',
#   'visitor',
#   'join',
#   'us',
#   'insid',
#   'epflec',
#   'lab',
#   'open',
#   'day',
#   'epflecallab',
#   'ecal',
#   'epfl',
#   'designresearch',
#   'digitalinnov',
#   'httpstcopxrazr8xo1'],
#  ['now',
#   'epfl',
#   'offer',
#   'mscrobot',
#   'join',
#   'long',
#   'list',
#   'brillant',
#   'mind',
#   'robot',
#   'epflphd',
#   'httpstcomsnlgmpaol',
#   'httpstcoc0vpvlzrbv'],
#  ['from',
#   'epfl',
#   'spinoff',
#   'sundancefest',
#   'sensat',
#   'month',
#   'made',
#   'techcrunch',
#   'front',
#   'page',
#   'httpstcorag69bzvk',
#   'thank',
#   'joshconstin',
#   'dartseventeen',
#   'fongit1',
#   'swissnexsf',
#   'venturekick',
#   'masschallengech',
#   'prohelvetia',
#   'worldvrforum',
#   'lnco',
#   'cnp',
#   'markboulo',
#   'elastictim'],
#  ['camil',
#   '’',
#   'first',
#   'paper',
#   'epfl',
#   'offici',
#   'onlin',
#   'envscitech',
#   'kinet',
#   'inactiv',
#   'waterborn',
#   'enter',
#   'virus',
#   'ozon',
#   'httpstcokjfcbbihjp'],
#  ['epfl',
#   'impost',
#   'robot',
#   'fish',
#   'infiltr',
#   'school',
#   'zebrafish',
#   'switzerland',
#   'httpstcoj8tp5su3ht'],
#  ['data',
#   'scienc',
#   'mobil',
#   'confer',
#   'coorgan',
#   'epfl',
#   'sbb',
#   'cff',
#   'ff',
#   '31',
#   'janv',
#   '2018',
#   'httpstcopnam80x8tn',
#   'epfl',
#   'httpstco4ldoldo6uw'],
#  ['dgtswitzerland',
#   'lereseau',
#   'epflen',
#   'cybersecurityday',
#   'le',
#   'objetsconnecté',
#   'intelligenceartificiel',
#   'réalitéaugmenté',
#   'sont',
#   'le',
#   'point',
#   'sensibl',
#   'de',
#   'cybersécurité',
#   'httpstcoelpyorrs7'],
#  ['le',
#   'nouveau',
#   'programm',
#   'de',
#   'cour',
#   'eawag',
#   'axé',
#   'sur',
#   'la',
#   'pratiqu',
#   'peak',
#   'est',
#   'en',
#   'lign',
#   'httpstcocvhref9yhb',
#   'le',
#   'prochain',
#   'cour',
#   '«',
#   'relevé',
#   'écomorphologiqu',
#   'et',
#   'évaluat',
#   'de',
#   'rive',
#   'lacustr',
#   '»',
#   'aura',
#   'lieu',
#   'le',
#   '7',
#   'février',
#   'epfl',
#   'httpstcocbsxy8wduh',
#   'httpstcor14llnhb2w'],
#  ['chocol',
#   'amp',
#   'berri',
#   'vegan',
#   'cheesecak',
#   'epfl',
#   'cowork',
#   '✌🏽🌱',
#   'veganfood',
#   'epflfood',
#   'httpstcowpllsit0kd'],
# ...
#   'grätzel',
#   'open',
#   'access',
#   'epfl',
#   'httpstcotodcuwv0e7',
#   'httpstcowj0glsts7w'],
#  ['reuter',
#   'rank',
#   'epflen',
#   'europ',
#   '4th',
#   'innov',
#   'univers',
#   'imperi',
#   'cambridg',
#   'univers',
#   'httpstco8ov83oqah8'],
#  ['une',
#   'école',
#   'qui',
#   'arbor',
#   'la',
#   'plu',
#   'grand',
#   'façad',
#   'solair',
#   'au',
#   'mond',
#   'httpstcot84i2mbiun',
#   'pv',
#   'enr',
#   'solar',
#   'v',
#   'epfl',
#   'httpstco1rc2edm3bc'],
#  ['archiv',
#   'photo',
#   'offer',
#   'research',
#   'valu',
#   'exhibit',
#   'acmepfl',
#   'epflen',
#   'httpstcolnjbg0cmn',
#   'httpstcoi5lwefylxm'],
#  ['whi',
#   'innov',
#   'need',
#   'sustain',
#   'prof',
#   'chri',
#   'tucci',
#   'jo',
#   'verbeek',
#   'rajiv',
#   'srivastava',
#   'epfl',
#   'worldbank',
#   'goodpowwow',
#   'onlythegood',
#   'httpstcojt7hmcgny'],
#  ['cryogen',
#   'fab',
#   'chip',
#   'httpstcohmtp66wt6w',
#   'acsnano',
#   'matthia',
#   'imboden',
#   'epflen',
#   'wpdl',
#   'amp',
#   'david',
#   'bishop',
#   'buec',
#   'butweet',
#   'psw',
#   'nano',
#   'httpstcouui9tmgnxt'],
#  ['paper',
#   'collabor',
#   'epflen',
#   'virtual',
#   'fpga',
#   'runtim',
#   'cloud',
#   'publish',
#   'ieee',
#   'access',
#   'httpstcobiqcjzrjl8'],
#  ['the',
#   'first',
#   'lowcost',
#   'system',
#   'split',
#   'carbon',
#   'dioxid',
#   'httpstconhax6irai5',
#   'epflen'],
#  ['sarah',
#   'perrin',
#   'epfl',
#   'quitt',
#   'punta',
#   'arena',
#   'pour',
#   'la',
#   'haut',
#   'mer',
#   'stormi',
#   'weather',
#   'expect',
#   'next',
#   'hour',
#   '😷😝',
#   'aceexpedit',
#   'httpstcokm1p7dnpr4'],
#  ['bonnardv', 'epfl', 'cest', 'pour', 'vou'],
#  ['le',
#   'gafa',
#   'sontil',
#   'devenu',
#   'trop',
#   'puissant',
#   'httpstco9f9q98oxp',
#   'avec',
#   'charl',
#   'wyplosz',
#   'iheid',
#   'et',
#   'deni',
#   'gillet',
#   'epfl'],
#  ['gro',
#   'plan',
#   'sur',
#   'le',
#   'infect',
#   'grave',
#   'chez',
#   'le',
#   'nouveauné',
#   'httpstcobmpozyou0x',
#   'avec',
#   'jfellay',
#   'epfl',
#   'isbsib',
#   'egiannoni',
#   'chuvlausann'],
#  ['propriété',
#   'intellectuel',
#   'la',
#   'suiss',
#   'championn',
#   'du',
#   'mond',
#   'de',
#   'brevet',
#   'suiss',
#   'via',
#   'epfl',
#   'httpstco7zwhp1j03t'],
#  ['le',
#   'robot',
#   'du',
#   'futur',
#   'auront',
#   'de',
#   'yeux',
#   'suiss',
#   'httpstcolrvirfnywc',
#   'via',
#   'ictjournalch',
#   'vision',
#   'startup',
#   'switzerland',
#   'innov',
#   'gafam',
#   'epfl',
#   'httpstcojlgbaxvtkj'],
#  ['aurelberra',
#   'frederickaplan',
#   'sur',
#   'le',
#   'campu',
#   'le',
#   'règle',
#   'varient',
#   'entr',
#   'epfl',
#   'et',
#   'unil',
#   'mai',
#   'aussi',
#   'au',
#   'sein',
#   'de',
#   'chaqu',
#   'faculté',
#   'de',
#   'lunil'],
#  ['epfl',
#   'robot',
#   'eel',
#   'detect',
#   'water',
#   'pollut',
#   'internet',
#   'busi',
#   'switzerland',
#   'httpstcoluzvtvhqzm'],
#  ['lili',
#   'bêche',
#   'bien',
#   'chez',
#   'notr',
#   'oncl',
#   'ferdinand',
#   'nestor',
#   'napoleon',
#   'mang',
#   'allègrement',
#   'six',
#   'poulet',
#   'san',
#   'claquer',
#   'dargent',
#   'httpstcon2e6p5luuw'],
#  ['talk', 'sex', 'power', 'johnantonaki', 'epfl', 'httpstcoxzogadbp4d'],
#  ['la',
#   'newslett',
#   'robotiqu',
#   'epfl',
#   'septembr',
#   '2017',
#   'est',
#   'là',
#   'inscrivezv',
#   'et',
#   'profitez',
#   'de',
#   'activit',
#   'httpstcojokzxoverh'],
#  ['oobliviousrid',
#   'an',
#   'encrypt',
#   'system',
#   'hide',
#   'travel',
#   'data',
#   'uber',
#   'httpstcorcxh00hmqi',
#   'epfl',
#   'ht',
#   'r0xanaradu'],
#  ['mscaction',
#   'euh2020',
#   'esr',
#   'iman',
#   'amp',
#   'bartek',
#   'epfl',
#   'present',
#   'research',
#   'work',
#   '2017',
#   'research',
#   'day',
#   'epflenac',
#   'enacresearchday',
#   '😀👍👏',
#   'httpstcopiufk3cdna'],
#  ['trace',
#   'possibl',
#   'martian',
#   'biolog',
#   'activ',
#   'insid',
#   'meteorit',
#   'httpstcopzu3ng1vmp',
#   'oscienc',
#   'epflen',
#   'mar',
#   'httpstco4l1kod6rgm'],
#  ['lore25n',
#   'covestrogroup',
#   'imdeanano',
#   'epflen',
#   'ujinoticia',
#   'imperialcolleg',
#   'a',
#   'lot',
#   'european',
#   'institut',
#   'industri',
#   'inde',
#   'congrat'],
#  ['proud',
#   'see',
#   'epflen',
#   'top',
#   'most',
#   'intern',
#   'univers',
#   '2017',
#   'ethen',
#   'httpstcoxxxszgejwt',
#   'via',
#   'philbati',
#   'timeshigh'],
#  ['whi',
#   'we',
#   'read',
#   'wikipedia',
#   'leila',
#   'zia',
#   'joint',
#   'work',
#   'progress',
#   'gesisorg',
#   'epfl',
#   'stanford',
#   'wikipedia',
#   '’',
#   'readership',
#   'httpstcoockxeddtcn',
#   'httpstco15wpb7m1bb'],
#  ['rosicrucioprotest',
#   'cardinaldolan',
#   'took',
#   'the',
#   'piss',
#   '1',
#   'traditionalcathol',
#   'fatherjenkin',
#   '💡👉httpstcoobwvlkso6f',
#   'trumpinaugur'],
#  ['here',
#   'practic',
#   'step',
#   'institut',
#   'take',
#   'make',
#   'progress',
#   'openaccess',
#   'journey',
#   'httpstco518lm0ymsn',
#   'httpstcoy8lnj3lgov'],
#  ['marcelsalath',
#   'a',
#   'back',
#   'tri',
#   'recruit',
#   'i',
#   'said',
#   'thank',
#   'thank',
#   'mayb',
#   'hasti',
#   'analysi',
#   'puzzl',
#   'sure',
#   'repli',
#   'i',
#   'got',
#   'led',
#   'think',
#   'employe',
#   'didnt',
#   'realli',
#   'understood',
#   'meant',
#   'work'],
#  ['rlerigni',
#   'sneedit',
#   'il',
#   'doit',
#   'bien',
#   'avoir',
#   'de',
#   'ressourc',
#   'quelqu',
#   'part',
#   'pour',
#   'un',
#   'premier',
#   'standard',
#   'csl',
#   'zotero',
#   'en',
#   'droit',
#   'françai'],
#  ['martinvetterli',
#   'epflen',
#   'epfl',
#   'congratul',
#   'wish',
#   'much',
#   'success',
#   'martindahinden'],
#  ['get',
#   'hand',
#   'dirti',
#   'make',
#   'fast',
#   'slow',
#   'workshop',
#   'thursday',
#   'just',
#   '2',
#   'spot',
#   'left',
#   'epfl',
#   'httpstcodp3fdxfp3z'],
#  ['lorsqu',
#   'lintellig',
#   'artificiel',
#   'compos',
#   'de',
#   'mélodi',
#   'authentiqu',
#   'httpstco4qqqksoafm',
#   'epfl',
#   'robot'],
#  ['the',
#   'gene',
#   'behind',
#   'follicularlymphoma',
#   'httpstcos48gvdstqa',
#   'epflen',
#   'sciencetm'],
#  ['univers',
#   'cargobik',
#   'share',
#   'lausann',
#   'epfl',
#   'httpstcovcqxjwcrfr',
#   'httpstcovhhnid4xqm'],
#  ['31052017',
#   'm',
#   'j',
#   'fox',
#   'foundat',
#   'i',
#   'research',
#   'fund',
#   'httpstcopzhx72iq33',
#   'epfl',
#   'michaeljfoxorg'],
#  ['thi',
#   'tuesday',
#   'join',
#   'us',
#   'free',
#   'mfe',
#   'practition',
#   'seminar',
#   'epfl',
#   'investglass',
#   'httpstcor7ml9nj9lo',
#   'ai',
#   'bigdata',
#   'roboadvisor',
#   'epfl'],
#  ['impressionnant',
#   'présentat',
#   'de',
#   'activité',
#   'du',
#   'centr',
#   'de',
#   'neuroprothès',
#   'de',
#   'l',
#   'epfl',
#   'httpstco3wjjjpb40a'],
#  ['reward',
#   'long',
#   'review',
#   'process',
#   'bürgi',
#   'et',
#   'al',
#   'epfl',
#   'help',
#   'understand',
#   'rarediseas',
#   'well',
#   'done',
#   'httpstcoftcnk40ssm'],
#  ['swisslitho',
#   'amp',
#   'epflen',
#   'make',
#   'nanopattern',
#   'silicon',
#   'thermal',
#   'scan',
#   'probe',
#   'lithographi',
#   'nanofabr',
#   'httpstco0xczhd4kon',
#   'httpstcoptubxymebp'],
#  ['the',
#   'board',
#   'swiss',
#   'feder',
#   'institut',
#   'technolog',
#   'announc',
#   'appoint',
#   'three',
#   'professor',
#   'epfl',
#   'httpstcou8sf3qyyqc'],
#  ['just',
#   'arriv',
#   'seedstarssummit',
#   'epfl',
#   'salad',
#   'amp',
#   'nespresso',
#   'disrupt',
#   'disconcert',
#   'coffe',
#   'break',
#   'look',
#   'fwd',
#   'plenari',
#   'excit',
#   'httpstcorkcrhmvit4'],
#  ['the', 'latest', 'lîlot', 'dashdawai', 'httpstcod76buifpkw', 'epfl'],
#  ['en',
#   'direct',
#   'sur',
#   'periscop',
#   'get',
#   'kick',
#   'jordimontserrat',
#   'aitcamp',
#   'epfl',
#   'httpstcojogvkdfeln'],
#  ['andrisilbi',
#   'ich',
#   'würde',
#   'meinen',
#   'exzellenz',
#   'zahlt',
#   'sich',
#   'au',
#   'glückwunsch',
#   'eth',
#   'félicit',
#   'au',
#   'epfl'],
#  ['migrat',
#   'ver',
#   'saphana',
#   'epfl',
#   'projet',
#   'réussi',
#   'et',
#   'accompagné',
#   'par',
#   'teamwork',
#   'casestudi',
#   'témoignag',
#   'httpstcoqdhjd4aoy'],
#  ['but', 'woman', 'samsam86', 'epfl', 'httpstcohm1ccy2pln'],
#  ['the',
#   'last',
#   'thing',
#   'i',
#   'would',
#   'want',
#   'palantir',
#   'privat',
#   'sv',
#   'data',
#   'mine',
#   'corpor',
#   'own',
#   'peter',
#   'thiel',
#   'anywher',
#   'near',
#   'even',
#   'singl',
#   'bit',
#   'digit',
#   'ident',
#   'httpstcorssxorvwmg'],
#  ['le',
#   '16',
#   'janvier',
#   'aura',
#   'lieu',
#   'à',
#   'lenssib',
#   'la',
#   'conférenc',
#   'l',
#   '’',
#   'europ',
#   'doit',
#   'construir',
#   'la',
#   'premièr',
#   'time',
#   'machin',
#   'de',
#   'frederickaplan',
#   'professeur',
#   'en',
#   'humanité',
#   'numériqu',
#   'epfl',
#   'et',
#   'directeur',
#   'du',
#   'digit',
#   'human',
#   'lab',
#   '➡',
#   'programm',
#   'amp',
#   'inscript',
#   'en',
#   'lign',
#   'httpstcoealk3tvsem',
#   'numériqu'],
#  ['check',
#   'new',
#   'paper',
#   'the',
#   'intern',
#   'structur',
#   'dynam',
#   'chromatin',
#   'fiber',
#   'reveal',
#   'singlemolecul',
#   'fret',
#   'modul',
#   'hp1a',
#   'naturecomm',
#   'httpstco6onrmewcnb',
#   'epfl'],
#  ['przemek',
#   'kornatowski',
#   'share',
#   'experi',
#   'good',
#   'practic',
#   'open',
#   'startup',
#   'still',
#   'work',
#   'academia',
#   'drone',
#   'epfl',
#   'httpstcotw2m5h2tnt'],
#  ['le',
#   'lauréat',
#   'du',
#   'prix',
#   'durabili',
#   'le',
#   'concour',
#   'de',
#   'travaux',
#   'sur',
#   'la',
#   'durabilité',
#   'de',
#   'étudiant',
#   'unil',
#   'epfl',
#   'unildur',
#   'httpstcoaz7xlfk3da'],
#  ['comment',
#   'le',
#   'vach',
#   'sadapterontel',
#   'au',
#   'changement',
#   'climatiqu',
#   'httpstcooxyrjroudp',
#   'avec',
#   'stéphane',
#   'joost',
#   'epfl'],
#  ['we',
#   'proud',
#   'announc',
#   'startup',
#   'chosen',
#   'take',
#   'part',
#   'innosuiss',
#   'winter',
#   '18',
#   'startup',
#   'camp',
#   'cohort',
#   'san',
#   'francisco',
#   'usa',
#   'see',
#   'soon',
#   'swissnexsf',
#   'swissnex',
#   'innosuiss',
#   'sanfrancisco',
#   'smartpark',
#   'smartmobl',
#   'smartciti',
#   'ethspinoff',
#   'swissstartup',
#   'httpstcot606fvecbz'],
#  ['epfl', 'morn', 'epfl', 'lausann', 'photographi', 'httpstco6ixddicblu'],
#  ['calcul',
#   'co2',
#   'emiss',
#   'biofuel',
#   'enough',
#   'httpstcorvquoky5tq',
#   'epflen',
#   'biofuel',
#   'eu',
#   'psd'],
#  ['today',
#   'osaopex',
#   'research',
#   'epflen',
#   'develop',
#   'opticalfib',
#   'could',
#   'lead',
#   'use',
#   '3dprint',
#   'repair',
#   'damag',
#   'tissu',
#   'httpstcoxlbsoh30io',
#   'via',
#   'opticalsocieti',
#   'eurekalert'],
#  ['conférenc',
#   'géothermi',
#   'de',
#   'surfac',
#   'et',
#   'développ',
#   'architecturaux',
#   'et',
#   'urbain',
#   'du',
#   'souterrain',
#   '15',
#   'juin',
#   '17h',
#   'epfl',
#   'httpstcorzz6b6brrw',
#   'httpstco1fat8de575'],
#  ['danish',
#   'school',
#   'instal',
#   'world',
#   '’',
#   'largest',
#   'solar',
#   'façad',
#   'httpstcovui3aaz3z6',
#   'epflen',
#   'copenhagen',
#   'switzerland',
#   'clean',
#   'energi',
#   'green',
#   'httpstcoqein9qwqol'],
#  ['interessant',
#   'artikel',
#   'von',
#   'mirkobischberg',
#   'epfl',
#   'au',
#   'texa',
#   'virtualr',
#   'scienc',
#   'art',
#   'evolut',
#   'der',
#   'maschinen',
#   'httpstcodnot4oimmv'],
#  ['fantast',
#   'primat',
#   'regain',
#   'control',
#   'paralyz',
#   'limb',
#   'httpstcobtfmcsw0xp',
#   'via',
#   'epflen',
#   'vdtech',
#   'httpstcoeek6g1vnm5'],
#  ['silent➕accur',
#   '21st',
#   'centuri',
#   'mechanicclock',
#   'epfl',
#   'unveil',
#   'neuchatel',
#   'citi',
#   'hall',
#   'httpstcoceuog4myqi'],
#  ['therapeut',
#   'robot',
#   'may',
#   'soon',
#   'assist',
#   'patient',
#   'after',
#   'stroke',
#   'httpstcokzbzzlzn5c',
#   'via',
#   'riarobot',
#   'ft',
#   'mit',
#   'epflen',
#   'httpstcofpkkytclij'],
#  ['great',
#   'event',
#   'opportun',
#   'network',
#   'next',
#   'week',
#   'rolex',
#   'center',
#   'epflen',
#   'see',
#   'meilleurduwebch',
#   '–',
#   'httpstcoumgkc3ot0d',
#   'httpstcoupvwgqkpez'],
#  ['epfl',
#   'presid',
#   'martinvetterli',
#   'speak',
#   'tonight',
#   'venture2017',
#   'competit',
#   'kickoff',
#   'epflen',
#   'rolex',
#   'learn',
#   'center',
#   'httpstcowsosmmrtbl'],
#  ['sandec',
#   '’',
#   'fabiansuter1',
#   'next',
#   'mooc',
#   'public',
#   'health',
#   'engin',
#   'humanitarian',
#   'context',
#   'start',
#   '6',
#   'nov',
#   '2017',
#   'epfl',
#   'icrc',
#   'httpstcotakzfgo7zx',
#   'httpstco09hxnyityk'],
#  ['lausann',
#   'et',
#   'la',
#   'riponn',
#   'comment',
#   'valoris',
#   'au',
#   'mieux',
#   'le',
#   'place',
#   'dan',
#   'le',
#   'vill',
#   'httpstcoknbo1qjpfq',
#   'avec',
#   'jchenal',
#   'epfl'],
#  ['lausann',
#   'et',
#   'la',
#   'riponn',
#   'comment',
#   'valoris',
#   'au',
#   'mieux',
#   'le',
#   'place',
#   'dan',
#   'le',
#   'vill',
#   'httpstcosyqnwjmzzx',
#   'avec',
#   'jchenal',
#   'epfl'],
#  ['effet',
#   'de',
#   'nanoparticul',
#   'sur',
#   'le',
#   'cellul',
#   'immunitair',
#   'humain',
#   'se',
#   'former',
#   'pour',
#   'mieux',
#   'comprendr',
#   'le',
#   'enjeux',
#   'lié',
#   'à',
#   'la',
#   'sécurité',
#   'de',
#   'nanoobjetsnanoparticul',
#   'format',
#   'epfl',
#   'sur',
#   'nanonmatériaux',
#   'httpstcold04jbxpsw',
#   'httpstco27enjydfx9'],
#  ['elliottrham',
#   'winstonmeiii',
#   'send',
#   'envelop',
#   'swiss',
#   'policevalai',
#   'help',
#   'take',
#   'racist',
#   'tortur',
#   'sexual',
#   'pervert',
#   'like',
#   'oskarfreysing',
#   'whose',
#   'polic',
#   'rape',
#   '7',
#   'year',
#   'old',
#   'boy',
#   'dont',
#   'get',
#   'investig',
#   'even',
#   'found',
#   'child',
#   'porn',
#   'on',
#   'polic',
#   'laptop',
#   'less',
#   'switzerland',
#   'nazi',
#   'epfl',
#   'unifr',
#   'metoo',
#   'httpstcohjbhwul4pv'],
#  ['footersi',
#   'fhll',
#   'lausann',
#   'end',
#   'solutionssolar',
#   'lab',
#   'develop',
#   'with',
#   'httpstcoefz6cwdb96'],
#  ['epfl',
#   'go',
#   'httpstcogo0zwhqt8d',
#   '…',
#   '…',
#   '…',
#   '…',
#   '…',
#   '…',
#   '…',
#   '…',
#   'read',
#   'campaign',
#   '2020',
#   'elect'],
#  ['onli',
#   'space',
#   'avail',
#   'sign',
#   'sdscdatasci',
#   'epflen',
#   'datajamday',
#   'httpstcovp03plbbr7',
#   'datasci',
#   'opendata',
#   'httpstcoxjkykw636q'],
#  ['jouer',
#   'dan',
#   'un',
#   'muséecest',
#   'nouveau',
#   'ça',
#   'venez',
#   'découvrir',
#   'le',
#   'prototyp',
#   'à',
#   '16',
#   'heur',
#   'epflartlab',
#   'museomixch',
#   'epfl',
#   'httpstcotcovytrn9i'],
#  ['want',
#   'overview',
#   '1st',
#   'eight',
#   'sdscdatasci',
#   'excit',
#   'project',
#   'start',
#   'fall',
#   'collabor',
#   'eth',
#   'domain',
#   'institut',
#   'ethen',
#   'epflen',
#   'empach',
#   'psichen',
#   'wslresearch',
#   'eawagresearch',
#   'httpstconr5ni3chy4',
#   'datasci',
#   'httpstcoktstr2m5yi'],
#  ['epfl',
#   'student',
#   'get',
#   'handson',
#   'experi',
#   '“',
#   'made',
#   'china',
#   '”',
#   'httpstcodkgmxia7tq',
#   'epfl'],
#  ['new',
#   'articl',
#   'epfl',
#   'team',
#   'systemat',
#   'studi',
#   'impact',
#   'oper',
#   'condit',
#   'degrad',
#   'perovskit',
#   'solarcel',
#   'read',
#   'free',
#   'httpstcovbgwifasea',
#   'httpstcopo2quiakbh'],
#  ['i',
#   'strongli',
#   'encourag',
#   'anyon',
#   'epflen',
#   'appli',
#   'pm',
#   'want',
#   'info',
#   'event',
#   'went',
#   'last',
#   'year',
#   'fantast',
#   'ping',
#   'epfllibrari',
#   'httpstcohwhyyevln4'],
#  ['epfl',
#   'veuillez',
#   'retir',
#   'ce',
#   'zizi',
#   'de',
#   'vue',
#   'où',
#   'je',
#   'vou',
#   'dénonc',
#   'à',
#   'la',
#   'manif',
#   'pour',
#   'tou',
#   '😇',
#   'httpstcobvuygd07tv'],
#  ['le',
#   'président',
#   'jcangelini',
#   'accueil',
#   'le',
#   'représent',
#   'de',
#   'epfl',
#   'à',
#   'portivechju',
#   'pour',
#   '3',
#   'jour',
#   'httpstcogts6lu5tnr'],
#  ['join',
#   'us',
#   'april',
#   '26',
#   'startup',
#   'champion',
#   'seed',
#   'night',
#   'epfl',
#   'showcas',
#   '24',
#   'worldclass',
#   'startup',
#   'httpstco89ziiby5f',
#   'champsnight',
#   'httpstcou4fnmegdup'],
#  ['final', 'day', 'fems2017', 'look', 'forward', 'insectmicrob', 'session'],
#  ['the',
#   'swisstech',
#   'convent',
#   'center',
#   'lausann',
#   'look',
#   '👌☀️',
#   'ahead',
#   'today',
#   'uefa',
#   'nationsleagu',
#   'draw',
#   'watch',
#   'live',
#   'httpstcoxdbiszjw1u',
#   '1200cet',
#   'httpstcoe2ogm9ze7v'],
#  ['jurist',
#   'utilisez',
#   'le',
#   'guid',
#   'de',
#   'citat',
#   'de',
#   'référenc',
#   'juridiqu',
#   'reflex',
#   'sneedit',
#   'httpstcoxiizqtsr9z',
#   'référenc',
#   'bibliographi',
#   'httpstcozjy1detl'],
#  ['congrat', 'epflen', 'httpstcofer6wwr7fc'],
#  ['still',
#   'wonder',
#   'best',
#   'engin',
#   'univers',
#   'world',
#   'ethen',
#   'epflen',
#   'top',
#   '10',
#   'thinkswiss',
#   'httpstco50aucbavcm',
#   'httpstco3rjiief5ag'],
#  ['merci',
#   'à',
#   'martinvetterli',
#   'pour',
#   'son',
#   'soutien',
#   'dan',
#   'la',
#   'création',
#   'dun',
#   'campu',
#   'carboneutr',
#   'à',
#   'lhorizon',
#   '2020',
#   'campu',
#   'durabl',
#   'epfl',
#   'est',
#   'déjà',
#   'au',
#   'travail',
#   'afin',
#   'datteindr',
#   'cet',
#   'objectif',
#   'trè',
#   'ambitieux',
#   'httpstco1kcnfc67xr'],
#  ['healthi',
#   'mitochondria',
#   'could',
#   'stop',
#   'alzheim',
#   'httpstcos3gmguc9sf',
#   'via',
#   'epflen',
#   'vdtech',
#   'research',
#   'httpstcot9oxzgtx4h'],
#  ['soon', 'start', 'httpstcoevlw3kf6v'],
#  ['thi',
#   'confer',
#   'go',
#   'awesom',
#   'realli',
#   'excit',
#   'teach',
#   'workshop',
#   'day',
#   'ai',
#   'machinelearn',
#   'datasci',
#   'httpstconkj1g5q9ri'],
#  ...]

# %% [markdown]
# #### 2. Vectorize the preprocessed text by implementing the TF/IDF function.

# %%
# Functions for the TF/IDF implementation

# create the vocabulary
vocabulary = list(set([item for sublist in documents for item in sublist]))
vocabulary.sort()

def idf_values(vocabulary, documents):
    """
    It computes IDF scores, storing idf values in a dictionary.
    
    :param vocabulary: list of str, with the unique tokens of the vocabulary.
    :param documents: list of lists of str, with tokenized sentences.
    :return: dict with the idf values for each vocabulary word.
    """
    idf = {}
    df = {}
    num_documents = len(documents)
    for i, term in enumerate(vocabulary):
        df[term] = sum(term in doc for doc in documents)
        idf[term] = math.log(num_documents / df[term], math.e)
    return idf

def vectorize(document, vocabulary, idf):
    """
    It generates the vector for an input document (with normalization).
    
    :param document: list of str with the tokenized documents.
    :param vocabulary: list of str, with the unique tokens of the vocabulary.
    :param idf: dict with the idf values for each vocabulary word.
    :return: list of floats
    """
    vector = [0]*len(vocabulary)
    counts = Counter(document)
    max_count = counts.most_common(1)[0][1]
    for i,term in enumerate(vocabulary):
        vector[i] =  counts[term] / max_count * idf[term]
    return vector

# Compute IDF values and vectors
idf = idf_values(vocabulary, documents)
document_vectors = [vectorize(s, vocabulary, idf) for s in documents]

def cosine_similarity(v1,v2):
    """
    It computes cosine similarity.
    
    :param v1: list of floats, with the vector of a document.
    :param v2: list of floats, with the vector of a document.
    :return: float
    """
    
    sumxx, sumxy, sumyy = 0, 0, 0
    for i in range(len(v1)):
        x = v1[i]; y = v2[i]
        sumxx += x*x
        sumyy += y*y
        sumxy += x*y
    if sumxy == 0:
            result = 0
    else:
            result =  sumxy / math.sqrt(sumxx * sumyy)
    return result

def search_vec(query, topk):
    """
    It computes the search result (get the topk documents).
    
    :param query: str
    :param topk: int
    """
    docs = []
    q = query.split()
    q = [stemmer.stem(w) for w in q]
    query_vector = vectorize(q, vocabulary, idf)
    scores = [[cosine_similarity(query_vector, document_vectors[d]), d] for d in range(len(documents))]
    scores.sort(key=lambda x: -x[0])
    for i in range(topk):
        docs.append(scores[i][1])
#         print(i)
    return docs

# HINTS
# natural logarithm function
#     math.log(n,math.e)
# Function to count term frequencies in a document
#     Counter(document)
# most common elements for a list
#     counts.most_common(1)

# %% [markdown]
# #### 3. Test your method by searching for the query  𝑄=‘‘𝑏𝑎𝑘𝑖𝑛𝑔″  and find the top-ranked documents according to the TF/IDF rank.

# %%
# Reference code using scikit-learn
tf = TfidfVectorizer(analyzer='word', ngram_range=(1,1), min_df = 1, stop_words = 'english')
features = tf.fit_transform(original_documents)
npm_tfidf = features.todense()
new_features = tf.transform(['baking'])

cosine_similarities = linear_kernel(new_features, features).flatten()
related_docs_indices = cosine_similarities.argsort()[::-1]
topk = 5
for i in range(topk):
    print(original_documents[related_docs_indices[i]])
# Out:
# @Repub_News @EPFL_en you are in Russian media =)
# Human genomics of infection and immunity, working closely with engineering and clinical colleagues @EPFL @CHUVLausanne. Please get in touch!
# L'app pour «liker» en direct les transports publics https://t.co/3HbkTnIE3Q #epfl
# Dr. Julien Faget from @epflSV @EPFL_en will talk about flow cytometry unsupervised analyses: from immune signature to functional biology https://t.co/tAQF8VOLQS
# The Swiss Team has won the Solar Decathlon competition  via @EPFL_en / Congrats! @Swiss_Living #VDtech https://t.co/dY437yk4su

# %% [markdown]
# #### 4.Compare your implementation with the existing implementation of scikit-learn library.
#
# In this part, we consider the scikit reference code as an “oracle” that supposedly gives the correct result. Your task is to compare your implemented tf-idf retrieval model with this oracle for the following queries "computer science", "IC school", "information systems" on the **epfldocs.txt** collection.
#
# For this exercise, you need to replace **bread.txt** in the first cell with **epfldocs.txt** and rerun all the cells from the begining.

# %%
# Retrieval oracle 
tf = TfidfVectorizer(analyzer='word', ngram_range=(1,1), min_df = 1, stop_words = 'english')
features = tf.fit_transform(original_documents)
npm_tfidf = features.todense()

def search_vec_sklearn(query, features, threshold=0.1):
    """
    Return all document ids that that have cosine similarity with the query larger than a threshold.
    
    :param query: str
    :param features: ndarray
    :param threshold: float
    :return: list of int
    """
    new_features = tf.transform([query])
    cosine_similarities = linear_kernel(new_features, features).flatten()
    related_docs_indices, cos_sim_sorted = zip(*sorted(enumerate(cosine_similarities), key=itemgetter(1), 
                                                       reverse=True))
    doc_ids = []
    for i, cos_sim in enumerate(cos_sim_sorted):
        if cos_sim < threshold:
            break
        doc_ids.append(related_docs_indices[i])
    return doc_ids

# %%
ret_ids = search_vec_sklearn('computer science', features)
for i, v in enumerate(ret_ids):
    print(original_documents[v])
# Out:
# Exciting News: "World University Rankings 2016-2017 by subject: computer science" No1 @ETH &amp; @EPFL on No8. Congrats https://t.co/ARSlXZoShQ
# New computer model shows how proteins are controlled "at a distance" https://t.co/zNjK3bZ6mO  via @EPFL_en #VDtech https://t.co/b9TglXO4KD
# An interview with Patrick Barth, a new @EPFL professor who combines protein #biophysics with computer modeling https://t.co/iJwBaEbocj
# Exposure Science Film Hackathon 2017 applications open! Come join our Scicomm-film-hacking event! #Science #scicomm https://t.co/zwtKPlh6HT
# Le mystère Soulages éblouit la science @EPFL  https://t.co/u3uNICyAdi
# @cwarwarrior @EPFL_en @EPFL Doing science at @EPFL_en is indeed pretty cool!!! Thank you for visiting!!!
# Blue Brain Nexus: an open-source tool for data-driven science https://t.co/m5yTgXf7ym #epfl
# Swiss Data Science on Twitter: "Sign up for @EPFL_en #DataJamDays: learn more a… https://t.co/kNVILHWPGb, see more https://t.co/2wg3BbHBNq
# The registration for Exposure Science Film Hackathon 2017 is open! #scicomm #lausanne #epfl #unil https://t.co/mY5jlwsXUD
# Know someone who has promoted sound #science? Less than 2 weeks to nominate them for the #MaddoxPrize. https://t.co/POnZtf3vFT
# #sleep #neuroscience #Neurosciences #science Healthy mitochondria could stop Alzheimer's https://t.co/rioZv4axxN #epfl
# Its about Energy &amp; People ! Blue Brain Nexus: an open-source tool for data-driven science https://t.co/1kTFeYqZe6 #epfl
# Blue Brain Nexus: an open-source tool for data-driven science https://t.co/Hou5tl7RoJ  via @EPFL_en #VDtech https://t.co/eftNaVCNh6
# New report on risk of misuse of life science research https://t.co/6HaoSkJTmZ #epfl  @ScnatCH https://t.co/VmkwW0Q2Gq
# The internet is amplifying the popularity of irrational food fads. Time for some science, says @EPFL_en https://t.co/MPPlAaHJ3X
# Deep Learning on Graphs, the Christmas lecture of @EPFL_en's course A Network Tour of Data Science. https://t.co/0Ke069OMBn https://t.co/o84K23WBLm
# Today I visited my friend @wonderqueens at @EPFL_en who showed me around how unbelievably cool is this place for doing science 😍 Thanks!! https://t.co/kWDnn0UXMN
# Hey #ASHG17 trainees, looking for a postdoc in genomics? Come to Switzerland: lake, mountains, exciting science: https://t.co/JaQq6zQKdC
# Noir c'est noir? Les Outrenoirs de Pierre Soulages | CULTURE/ART/SCIENCE https://t.co/6ZTZov8ylH #epfl #epflcampus
# Blue Brain Nexus: An open-source knowledge graph for data-driven science https://t.co/XcrufBSg5a via @EPFL_en @EurekAlert @BlueBrainPjt @wake_sleep
# Data Science and Mobility Conference is co-organized by EPFL and SBB CFF FFS. 31 JANV 2018 https://t.co/PNAm80x8Tn - @EPFL https://t.co/4ldolDo6UW
# ETH Zürich und EPFL haben das Swiss Data Science Center eröffnet @ETH @EPFL_en @SDSCdatascience https://t.co/PdoHEAo9w6 https://t.co/OMaseBuL3L
# Interessanter Artikel von @MirkoBischBerg @EPFL aus Texas. #virtualreality #science #arts. Evolution der Maschinen https://t.co/dNOt4OimmV
# @MartinVetterli @EPFL setzt sich für open science ein. Wissen teilen für mehr Wirkung. https://t.co/4hMAZtA9Qa
# "Art and science collisions" - A presentation of art residence @CERN with Yunchul Kim and Helga Timko at @EPFL ----&gt; https://t.co/GT73OAEVOH
# Je rêve! même la science et l'innovation sont touchées par ce décret! Moyen-Age 2.0 #Trump #NoBanNoWall @EPFL https://t.co/gYcLIE4vHL @tdgch

# %%
queries = ["computer science", "IC school", "information systems"]

# %%
def compute_recall_at_k(predict, gt, k):
    """
    It computes the recall score at a defined set of retrieved documents.
    
    :param predict: list of predictions
    :param gt: list of actual data
    :param k: int
    """
    result_k = predict[:k]
    recall = sum(r in gt for r in result_k) / len(gt)
    return recall

# %%
def compute_precision_at_k(predict, gt, k):
    """
    It computes the precision score at a defined set of retrieved documents.
    
    :param predict: list of predictions
    :param gt: list of actual data
    :param k: int
    """
    result_k = predict[:k]
    precision = sum(r in gt for r in result_k) / k
    return precision

# %%
def compute_map(queries, K = 10):
    """
    It computes mean average precision (MAP) for a set of queries.
    
    :param queries: list of str
    :param K: int
    """
    map_score = 0
    for i, query in enumerate(queries):
        predict = search_vec(query, K)
        gt = search_vec_sklearn(query, features)
        p_int = []
        for k in range(K, 0, -1):
            pk = compute_precision_at_k(predict, gt, k)
            
            # Compute interpolated precision
            pint_k = max([pk] + p_int)
            
            # Prepend pint_k to p_int
            p_int.insert(0, pint_k)
        # Only consider precision values when retrieving a relevant document
        p_int_relevant = sum(p_int[i] for i, retrieved in enumerate(predict) if retrieved in gt)
        
        # Divide by number of relevant documents
        map_score += p_int_relevant / len(gt)
    map_score = map_score / len(queries)
    return map_score

# %%
compute_map(queries)
# Out:
# 0.34769230769230774

# %%
p_int = [5,4,3,4]
pk = 3.5
p_int_k = max([pk] + p_int)

# %%
p_int_k
# Out:
# 5
